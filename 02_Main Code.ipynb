# %%
class Agent():
    def __init__(self,state,parent,action,depth,step_cost,path_cost,heuristic_cost):
        self.state = state 
        self.parent = parent # parent Node
        self.action = action # move up, left, down, right
        self.depth = depth # depth of the Node in the tree
        self.step_cost = step_cost # g(n), the cost to take the step
        self.path_cost = path_cost # accumulated g(n), the cost to reach the current Node
        self.heuristic_cost = heuristic_cost # h(n), cost to reach goal state from the current Node
        
        # children  Node
        self.move_up = None 
        self.move_left = None
        self.move_down = None
        self.move_right = None

    # once the goal Node is found, track back to the root Node and print out the path
    def print_path(self):
        # create FILO stacks to place the track
        action_track = [self.action]
        depth_track = [self.depth]
        state_track = [self.state]
        step_cost_track = [self.step_cost]
        path_cost_track = [self.path_cost]
        heuristic_cost_track = [self.heuristic_cost]

        # add Agent information as tracing back up the tree
        while self.parent:
            self = self.parent
            action_track.append(self.action) #the action that was taken to reach the node
            depth_track.append(self.depth) #the depth of the node in the search tree
            state_track.append(self.state) #the state of the node
            step_cost_track.append(self.step_cost) # the cost of taking the action to reach the node
            path_cost_track.append(self.path_cost)  #the total cost of reaching the node, which is the sum of the path cost and the heuristic cost
            heuristic_cost_track.append(self.heuristic_cost)

        # print out the path
        step_counter = 0
        while state_track:
            print ('step',step_counter)
            print (state_track.pop())
            print ('action=',action_track.pop(),', depth=',str(depth_track.pop()),', step cost=',str(step_cost_track.pop()),', total_cost=',
            str(path_cost_track.pop() + heuristic_cost_track.pop()),'\n')
            
            step_counter += 1


    # see if moving up is valid
    def moving_up(self):
        index_0=[i[0] for i in np.where(self.state==0)] #searches the index value of 0 inthe current state
        if index_0[0] == 2: #if 0 value is already in the top row cannot move futher
            return None
        else:
            lower_value = self.state[index_0[0]+1,index_0[1]] # If not in the top row, then it can move up one row. get the value of the tile that the 0 value will swap with.
            current_state = self.state.copy()  #create copy of the new state
            current_state[index_0[0],index_0[1]] = lower_value  #this line swaps the 0 value with the tile that is below it (index position of 0 in matrix)
            current_state[index_0[0]+1,index_0[1]] = 0   #This line sets the tile that the 0 value was swapped with to be 0.
            return current_state,lower_value  #This line returns a tuple containing the new puzzle state after moving the 0 value up and the value of the tile that the 0 value was swapped with

    # see if moving down is valid
    def moving_down(self):
        # index of the empty tile
        index_0=[i[0] for i in np.where(self.state==0)] 
        if index_0[0] == 0:
            return None
        else:
            up_value = self.state[index_0[0]-1,index_0[1]] # value of the upper tile
            current_state = self.state.copy()
            current_state[index_0[0],index_0[1]] = up_value
            current_state[index_0[0]-1,index_0[1]] = 0
            return current_state,up_value

    # see if moving left is valid
    def moving_left(self):
        index_0=[i[0] for i in np.where(self.state==0)] 
        if index_0[1] == 2:
            return None
        else:
            right_value = self.state[index_0[0],index_0[1]+1] # value of the right tile
            current_state = self.state.copy()
            current_state[index_0[0],index_0[1]] = right_value
            current_state[index_0[0],index_0[1]+1] = 0
            return current_state,right_value

    # see if moving right is valid
    def moving_right(self):
        index_0=[i[0] for i in np.where(self.state==0)] 
        if index_0[1] == 0:
            return None
        else:
            left_value = self.state[index_0[0],index_0[1]-1] # value of the left tile
            current_state = self.state.copy()
            current_state[index_0[0],index_0[1]] = left_value
            current_state[index_0[0],index_0[1]-1] = 0
            return current_state,left_value
        
    # return user specified heuristic cost
    def get_h_cost(self,current_state,goal_state,heuristic_function,path_cost,depth):
        if heuristic_function == 'manhattan': #depending on the heuristic function calculates the heuristic cost by manhattan distance
            return self.h_manhattan_cost(current_state,goal_state) #will call manhattan function to calculate the cost between each tile and its correct position
        # In the original game the step cost is the number on the tile
        # I have come up with the relaxed version of the problem and, I made all the step cost as 1
        # made it a Greedy search with manhattan heuristic function
        elif heuristic_function == 'fair_manhattan':
            return self.h_manhattan_cost(current_state,goal_state) - path_cost + depth

    # return heuristic cost: sum of Manhattan distance to reach the goal state
    def h_manhattan_cost(self,current_state,goal_state): #the sum of the Manhattan distances between each tile and its correct position.
        current = current_state
        # digit and coordinates they are supposed to be
        goal_position = {1:(0,0),2:(0,1),3:(0,2),8:(1,0),0:(1,1),4:(1,2),7:(2,0),6:(2,1),5:(2,2)} 
        man_sum = 0
        for i in range(3):# for row in current position
            for j in range(3): # for column
                if current[i,j] != 0:
                    man_sum += sum(abs(a-b) for a,b in zip((i,j), goal_position[current[i,j]])) #the zip fun. pairs up two tuples which contains the current position and goal position of a tile the list comprehension of the distance between them
        return man_sum
        

#BFS   (First in First out)       

    def breadth_first_search(self, goal_state):
        fringe = [self] # queue of found but unvisited_nodes Nodes, (root node)
        fringe_n_popped = 0 # number of Nodes popped off the fringe
        fringe_max_length = 1 # max number of Nodes in the fringe
        fringe_d = [0] #  fringe of Node depth
        path_cost_fringe = [0] # nodes in the fringe for path cost
        visited_nodes = set([]) # record visited_nodes states
        
        # loop for each iteration 
        while fringe:
            # update maximum length of the fringe
            if len(fringe) > fringe_max_length:
                fringe_max_length = len(fringe)
                
            current_d = fringe_d.pop(0) # select and remove the depth for current node
            current_n = fringe.pop(0) # select and remove the first node in the fringe
            fringe_n_popped += 1
            current_p_cost = path_cost_fringe.pop(0) # select and remove the path cost for reaching current node
            visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # saves the visited_nodes nodes in the tuple to avoid repeatition 
            
            # when the goal state is found, track back to the root node and print out the path
            if np.array_equal(current_n.state,goal_state):
                current_n.print_path()
                print ('Nodes Poped',str(fringe_n_popped))
                print ('Max Fringe Size', str(fringe_max_length))
                return 'Search Complete'      
            else:                
                # see if moving lower tile up is a valid move
                if current_n.moving_up():
                    current_state,lower_value = current_n.moving_up()
                    # check if the resulting node is already visited_nodes to avoid repeatation
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=current_d+1,\
                                              step_cost=lower_value,path_cost=current_p_cost+lower_value,heuristic_cost=0)
                        fringe.append(current_n.move_up) #we add the node to the end of the fringe with append
                        fringe_d.append(current_d+1)
                        path_cost_fringe.append(current_p_cost+lower_value)

                # see if moving upper tile down is a valid move
                if current_n.moving_down():
                    current_state,up_value = current_n.moving_down()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=current_d+1,\
                                              step_cost=up_value,path_cost=current_p_cost+up_value,heuristic_cost=0)
                        fringe.append(current_n.move_down) #we add to the end of the fringe by append since it is BFS
                        fringe_d.append(current_d+1)
                        path_cost_fringe.append(current_p_cost+up_value)

                # see if moving right tile to the left is a valid move
                if current_n.moving_left():
                    current_state,right_value = current_n.moving_left()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=current_d+1,\
                                              step_cost=right_value,path_cost=current_p_cost+right_value,heuristic_cost=0)
                        fringe.append(current_n.move_left)
                        fringe_d.append(current_d+1)
                        path_cost_fringe.append(current_p_cost+right_value)
                
               # see if moving left tile to the right is a valid move
                if current_n.moving_right():
                    current_state,left_value = current_n.moving_right()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes: 
                        # create a new child node
                        current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=current_d+1,\
                                              step_cost=left_value,path_cost=current_p_cost+left_value,heuristic_cost=0)
                        fringe.append(current_n.move_right) 
                        fringe_d.append(current_d+1)
                        path_cost_fringe.append(current_p_cost+left_value)


#UCS (cost of all the actions to get to root node), An extension of BFS that's guided by a prioritized fringe based on path cost

    def uniform_cost_search_BFS(self, goal_state):
        fringe = [(self,0)] # fringe of (found but unvisited_nodes, path cost), ordered by path cost(accumulated step cost)
        fringe_n_popped = 0 # number of nodes popped off the fringe
        fringe_max_length = 1 # max number of nodes in the fringe
        path_cost_fringe = [0] # fringe for path cost
        fringe_d = [(0,0)] # fringe of node depth, (depth, path cost)
        visited_nodes = set([]) # record visited_nodes
        # loop for each iteration 
        while fringe:
            # sort fringe based on path cost, in ascending order so it pops the node with least cost first from the fringe
            fringe = sorted(fringe, key=lambda x: x[1])
            fringe_d = sorted(fringe_d, key=lambda x: x[1])
            path_cost_fringe = sorted(path_cost_fringe, key=lambda x: x)
            
            # update maximum length of the fringe
            if len(fringe) > fringe_max_length:
                fringe_max_length = len(fringe)
                
            current_n = fringe.pop(0)[0] # select and remove the first node in the fringe
            fringe_n_popped += 1
            current_p_cost = path_cost_fringe.pop(0) #  select and remove the path cost for reaching current node
            current_d = fringe_d.pop(0)[0] # select and remove the depth for current node
            visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # avoid repeated state, which is represented as a tuple
            
            # when the goal state is found, track back to the root node and print out the path
            if np.array_equal(current_n.state,goal_state):
                current_n.print_path()
                print ('Nodes Poped',str(fringe_n_popped))
                print ('Max Fringe Size', str(fringe_max_length))
                return 'Search Completed'
            
            else:     

                # see if moving lower tile up is a valid move
                if current_n.moving_up():
                    current_state,lower_value = current_n.moving_up()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=current_d+1,\
                                              step_cost=lower_value,path_cost=current_p_cost+lower_value,heuristic_cost=0)
                        fringe.append((current_n.move_up,current_p_cost+lower_value)) # added back of the fringe but gets sorted
                        fringe_d.append((current_d+1,current_p_cost+lower_value))
                        path_cost_fringe.append(current_p_cost+lower_value)

                # see if moving upper tile down is a valid move
                if current_n.moving_down():
                    current_state,up_value = current_n.moving_down()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=current_d+1,\
                                              step_cost=up_value,path_cost=current_p_cost+up_value,heuristic_cost=0)
                        fringe.append((current_n.move_down,current_p_cost+up_value))
                        fringe_d.append((current_d+1,current_p_cost+up_value))
                        path_cost_fringe.append(current_p_cost+up_value)

                # see if moving right tile to the left is a valid move
                if current_n.moving_left():
                    current_state,right_value = current_n.moving_left()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=current_d+1,\
                                              step_cost=right_value,path_cost=current_p_cost+right_value,heuristic_cost=0)
                        fringe.append((current_n.move_left,current_p_cost+right_value))
                        fringe_d.append((current_d+1,current_p_cost+right_value))
                        path_cost_fringe.append(current_p_cost+right_value)

                # see if moving left tile to the right is a valid move
                if current_n.moving_right():
                    current_state,left_value = current_n.moving_right()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=current_d+1,\
                                              step_cost=left_value,path_cost=current_p_cost+left_value,heuristic_cost=0)
                        fringe.append((current_n.move_right,current_p_cost+left_value))
                        fringe_d.append((current_d+1,current_p_cost+left_value))
                        path_cost_fringe.append(current_p_cost+left_value)


#DFS (Last in First Out)(will find the shallowest solution)
          
    def depth_first_search(self, goal_state):     
        fringe = [self] # fringe of found but unvisited_nodes
        fringe_n_popped = 0 # number of nodes popped off the fringe
        fringe_max_length = 1 # max number of nodes in the fringe
        path_cost_fringe = [0] # fringe for path cost
        fringe_d = [0] # fringe of node depth
        visited_nodes = set([]) # record visited_nodes states
        # loop for each iteration 
        while fringe:
            # update maximum length of the fringe
            if len(fringe) > fringe_max_length:
                fringe_max_length = len(fringe)
            current_n = fringe.pop(0) # select and remove the first Agent in the fringe
            fringe_n_popped += 1 
            current_d = fringe_d.pop(0) # select and remove the depth for current node
            current_p_cost = path_cost_fringe.pop(0) # # select and remove the depth for current no# select and remove the path cost for reaching current node
            visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # avoid repeated state, which is represented as a tuple
            
            # when the goal state is found, track back to the root node and print out the path
            if np.array_equal(current_n.state,goal_state):
                current_n.print_path()
                print ('Nodes Poped',str(fringe_n_popped))
                print ('Max Fringe Size', str(fringe_max_length))
                return 'Search Complete'        
            else:      
                # see if moving lower tile up is a valid move
                if current_n.moving_up():
                    current_state,lower_value = current_n.moving_up()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=current_d+1,\
                                              step_cost=lower_value,path_cost=current_p_cost+lower_value,heuristic_cost=0)
                        fringe.insert(0,current_n.move_up) # inserted to the begining of the fringe so it pops the first
                        fringe_d.insert(0,current_d+1)
                        path_cost_fringe.insert(0,current_p_cost+lower_value)

                # see if moving upper tile down is a valid move
                if current_n.moving_down():
                    current_state,up_value = current_n.moving_down()
                    # check if the resulting Agent is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child Agent
                        current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=current_d+1,\
                                              step_cost=up_value,path_cost=current_p_cost+up_value,heuristic_cost=0)
                        fringe.insert(0,current_n.move_down) # inserted to the begining of the fringe
                        fringe_d.insert(0,current_d+1)
                        path_cost_fringe.insert(0,current_p_cost+up_value)

                # see if moving right tile to the left is a valid move
                if current_n.moving_left():
                    current_state,right_value = current_n.moving_left()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=current_d+1,\
                                              step_cost=right_value,path_cost=current_p_cost+right_value,heuristic_cost=0)
                        fringe.insert(0,current_n.move_left)
                        fringe_d.insert(0,current_d+1)
                        path_cost_fringe.insert(0,current_p_cost+right_value)

                # see if moving left tile to the right is a valid move
                if current_n.moving_right():
                    current_state,left_value = current_n.moving_right()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # create a new child node
                        current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=current_d+1,\
                                              step_cost=left_value,path_cost=current_p_cost+left_value,heuristic_cost=0)
                        fringe.insert(0,current_n.move_right)
                        fringe_d.insert(0,current_d+1)
                        path_cost_fringe.insert(0,current_p_cost+left_value)

         

#IDS, An extension of DFS that's guided by LIFO (we set the depth limit as an input) enter value greater than 14

    def iterative_deepening_DFS(self, goal_state):
        fringe_n_popped = 0 # number of nodes popped off the fringe
        fringe_max_length = 1 # max number of nodes in the fringe
        # search the tree that's 40 levels in depth
        for depth_limit in range(int(input('what is the dept limit: '))): #enter limit >=14
            fringe = [self] # fringe of found but unvisited_nodes nodes, FILO
            fringe_d = [0] # fringe of node depth
            path_cost_fringe = [0] # fringe for path cost
            visited_nodes = set([]) # record visited_nodes states
            while fringe:
                # update maximum length of the fringe
                if len(fringe) > fringe_max_length:
                    fringe_max_length = len(fringe)

                current_n = fringe.pop(0) # select and remove the first node in the fringe
                fringe_n_popped += 1 
                current_d = fringe_d.pop(0) # select and remove the depth for current node
                current_p_cost = path_cost_fringe.pop(0) # select and remove the path cost for reaching current node
                visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # add state, which is represented as a tuple

                # when the goal state is found, track back to the root node and print out the path
                if np.array_equal(current_n.state,goal_state):
                    current_n.print_path()
                    print ('Nodes Poped',str(fringe_n_popped))
                    print ('Max Fringe Size', str(fringe_max_length))
                    return 'Search Complete'

                else:              
                    if current_d < depth_limit:

                        # see if moving lower tile up is a valid move
                        if current_n.moving_up():
                            current_state,lower_value = current_n.moving_up()
                            # check if the resulting Agent is already visited_nodes
                            if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                                # create a new child Agent
                                current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=current_d+1,\
                                                      step_cost=lower_value,path_cost=current_p_cost+lower_value,heuristic_cost=0)
                                fringe.insert(0,current_n.move_up) #insert at the start of the fringe
                                fringe_d.insert(0,current_d+1)
                                path_cost_fringe.insert(0,current_p_cost+lower_value)

                        # see if moving upper tile down is a valid move
                        if current_n.moving_down():
                            current_state,up_value = current_n.moving_down()
                            # check if the resulting Agent is already visited_nodes
                            if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                                # create a new child Agent
                                current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=current_d+1,\
                                                      step_cost=up_value,path_cost=current_p_cost+up_value,heuristic_cost=0)
                                fringe.insert(0,current_n.move_down) # inserted to the begining of the fringe
                                fringe_d.insert(0,current_d+1)
                                path_cost_fringe.insert(0,current_p_cost+up_value)

                       # see if moving right tile to the left is a valid move
                        if current_n.moving_left():
                            current_state,right_value = current_n.moving_left()
                            # check if the resulting Agent is already visited_nodes
                            if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                                # create a new child Agent
                                current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=current_d+1,\
                                                      step_cost=right_value,path_cost=current_p_cost+right_value,heuristic_cost=0)
                                fringe.insert(0,current_n.move_left)
                                fringe_d.insert(0,current_d+1)
                                path_cost_fringe.insert(0,current_p_cost+right_value)

                        # see if moving left tile to the right is a valid move
                        if current_n.moving_right():
                            current_state,left_value = current_n.moving_right()
                            # check if the resulting Agent is already visited_nodes
                            if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                                # create a new child Agent
                                current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=current_d+1,\
                                                      step_cost=left_value,path_cost=current_p_cost+left_value,heuristic_cost=0)
                                fringe.insert(0,current_n.move_right)
                                fringe_d.insert(0,current_d+1)
                                path_cost_fringe.insert(0,current_p_cost+left_value)
                    

 #Greedy Search                       
    # search based on heuristic cost (manhattan distance)
    def greedy_search(self, goal_state):
        fringe = [(self,0)] # fringe of (found but unvisited_nodes, heuristic cost), ordered by heuristic cost
        fringe_n_popped = 0 # number of node popped off the fringe
        path_cost_fringe = [(0,0)] # fringe for path cost, (path_cost, heuristic cost)
        fringe_max_length = 1 # max number of node in the fringe
        fringe_d = [(0,0)] # fringe of node depth, (depth, heuristic cost)
        visited_nodes = set([]) # record visited_nodes states
        
        while fringe:
            # sort fringe based on heuristic cost, in ascending order
            fringe = sorted(fringe, key=lambda x: x[1])
            fringe_d = sorted(fringe_d, key=lambda x: x[1])
            path_cost_fringe = sorted(path_cost_fringe, key=lambda x: x[1])
            # update maximum length of the fringe
            if len(fringe) > fringe_max_length:
                fringe_max_length = len(fringe)
            current_n = fringe.pop(0)[0] # select and remove the first node in the fringe
            fringe_n_popped += 1 
            current_d = fringe_d.pop(0)[0] # select and remove the depth for current node
            current_p_cost = path_cost_fringe.pop(0)[0] # select and remove the path cost for reaching current node
            visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # avoid repeated state, which is represented as a tuple
            
            # when the goal state is found, track back to the root node and print out the path
            if np.array_equal(current_n.state,goal_state):
                current_n.print_path()
                print ('Agents Poped',str(fringe_n_popped))
                print ('Max Fringe Size', str(fringe_max_length))
                return 'Search Complete'
            else:     
                # see if moving lower tile up is a valid move
                if current_n.moving_up():
                    current_state,lower_value = current_n.moving_up()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # get heuristic cost
                        h_cost = self.h_manhattan_cost(current_state,goal_state)
                        # create a new child nodes
                        current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=current_d+1,\
                                              step_cost=lower_value,path_cost=current_p_cost+lower_value,heuristic_cost=h_cost)
                        fringe.append((current_n.move_up,h_cost))
                        fringe_d.append((current_d+1,h_cost))
                        path_cost_fringe.append((current_p_cost+lower_value,h_cost))

                # see if moving upper tile down is a valid move
                if current_n.moving_down():
                    current_state,up_value = current_n.moving_down()
                    # check if the resulting mode is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # get heuristic cost
                        h_cost = self.h_manhattan_cost(current_state,goal_state)
                        # create a new child nodes
                        current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=current_d+1,\
                                              step_cost=up_value,path_cost=current_p_cost+up_value,heuristic_cost=h_cost)
                        fringe.append((current_n.move_down,h_cost))
                        fringe_d.append((current_d+1,h_cost))
                        path_cost_fringe.append((current_p_cost+up_value,h_cost))
               
               # see if moving right tile to the left is a valid move
                if current_n.moving_left():
                    current_state,right_value = current_n.moving_left()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # get heuristic cost
                        h_cost = self.h_manhattan_cost(current_state,goal_state)
                        # create a new child nodes
                        current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=current_d+1,\
                                              step_cost=right_value,path_cost=current_p_cost+right_value,heuristic_cost=h_cost)
                        fringe.append((current_n.move_left,h_cost))
                        fringe_d.append((current_d+1,h_cost))
                        path_cost_fringe.append((current_p_cost+right_value,h_cost))

                # see if moving left tile to the right is a valid move
                if current_n.moving_right():
                    current_state,left_value = current_n.moving_right()
                    # check if the resulting nodes is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        # get heuristic cost
                        h_cost = self.h_manhattan_cost(current_state,goal_state)
                        # create a new child nodes
                        current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=current_d+1,\
                                              step_cost=left_value,path_cost=current_p_cost+left_value,heuristic_cost=h_cost)
                        fringe.append((current_n.move_right,h_cost))
                        fringe_d.append((current_d+1,h_cost))
                        path_cost_fringe.append((current_p_cost+left_value,h_cost))

#A* Search (g(n)+h(n)) search based on path cost + heuristic cost

    def a_star_search(self,goal_state,heuristic_function):
        fringe = [(self,0)] # fringe of (found but unvisited_nodes, path cost+heuristic cost), ordered by the second element
        fringe_n_popped = 0 # number of Agents popped off the fringe, measuring time performance
        fringe_max_length = 1 # max number of Agents in the fringe, measuring space performance
        fringe_d = [(0,0)] # fringe of node depth, (depth, path_cost+heuristic cost)
        path_cost_fringe = [(0,0)] # fringe for path cost, (path_cost, path_cost+heuristic cost)
        visited_nodes = set([]) # record visited_nodes states
        
        while fringe:
            # sort fringe based on path_cost+heuristic cost, in ascending order
            fringe = sorted(fringe, key=lambda x: x[1])
            fringe_d = sorted(fringe_d, key=lambda x: x[1])
            path_cost_fringe = sorted(path_cost_fringe, key=lambda x: x[1])
            # update maximum length of the fringe
            if len(fringe) > fringe_max_length:
                fringe_max_length = len(fringe)
                
            current_n = fringe.pop(0)[0] # select and remove the first node in the fringe
            fringe_n_popped += 1 
            current_d = fringe_d.pop(0)[0] # select and remove the depth for current node
            current_p_cost = path_cost_fringe.pop(0)[0] # select and remove the path cost for reaching current node
            visited_nodes.add(tuple(current_n.state.reshape(1,9)[0])) # avoid repeated state, which is represented as a tuple
            
            # when the goal state is found, track back to the root node and print out the path
            if np.array_equal(current_n.state,goal_state):
                current_n.print_path()
                print ('Agents Poped',str(fringe_n_popped))
                print ('Max Fringe Size', str(fringe_max_length))
                return 'Search Complete'
            else:     

                # see if moving lower tile up is a valid move
                if current_n.moving_up():
                    current_state,lower_value = current_n.moving_up()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        path_cost=current_p_cost+lower_value
                        depth = current_d+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(current_state,goal_state,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost
                        current_n.move_up = Agent(state=current_state,parent=current_n,action='up',depth=depth,\
                                              step_cost=lower_value,path_cost=path_cost,heuristic_cost=h_cost)
                        fringe.append((current_n.move_up, total_cost))
                        fringe_d.append((depth, total_cost))
                        path_cost_fringe.append((path_cost, total_cost))

                # see if moving upper tile down is a valid move
                if current_n.moving_down():
                    current_state,up_value = current_n.moving_down()
                    # check if the resulting Agent is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        path_cost=current_p_cost+up_value
                        depth = current_d+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(current_state,goal_state,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost
                        current_n.move_down = Agent(state=current_state,parent=current_n,action='down',depth=depth,\
                                              step_cost=up_value,path_cost=path_cost,heuristic_cost=h_cost)
                        fringe.append((current_n.move_down, total_cost))
                        fringe_d.append((depth, total_cost))
                        path_cost_fringe.append((path_cost, total_cost))
                    
                # see if moving right tile to the left is a valid move
                if current_n.moving_left():
                    current_state,right_value = current_n.moving_left()
                    # check if the resulting Agent is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        path_cost=current_p_cost+right_value
                        depth = current_d+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(current_state,goal_state,heuristic_function,path_cost,depth)
                        # create a new child Agent
                        total_cost = path_cost+h_cost
                        current_n.move_left = Agent(state=current_state,parent=current_n,action='left',depth=depth,\
                                              step_cost=right_value,path_cost=path_cost,heuristic_cost=h_cost)
                        fringe.append((current_n.move_left, total_cost))
                        fringe_d.append((depth, total_cost))
                        path_cost_fringe.append((path_cost, total_cost))

                # see if moving left tile to the right is a valid move
                if current_n.moving_right():
                    current_state,left_value = current_n.moving_right()
                    # check if the resulting node is already visited_nodes
                    if tuple(current_state.reshape(1,9)[0]) not in visited_nodes:
                        path_cost=current_p_cost+left_value
                        depth = current_d+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(current_state,goal_state,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost
                        current_n.move_right = Agent(state=current_state,parent=current_n,action='right',depth=depth,\
                                              step_cost=left_value,path_cost=path_cost,heuristic_cost=h_cost)
                        fringe.append((current_n.move_right, total_cost))
                        fringe_d.append((depth, total_cost))
                        path_cost_fringe.append((path_cost, total_cost))

# %%
import numpy as np
start_state= np.array([2,3,6,1,0,7,4,8,5]).reshape(3,3)
goal_state = np.array([1,2,3,4,5,6,7,8,0]).reshape(3,3)
print (start_state,'\n')
print (goal_state)
# Out:
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]

# %%
# calling the function 
root_node = Agent(state=start_state,parent=None,action=None,depth=0,step_cost=0,path_cost=0,heuristic_cost=0)

# %%
# search level by level with queue
root_node.breadth_first_search(goal_state)
# Out:
# step 0
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 3 6]
#  [1 7 0]
#  [4 8 5]]
# action= left , depth= 1 , step cost= 7 , total_cost= 7
#
# step 2
# [[2 3 6]
#  [1 7 5]
#  [4 8 0]]
# action= up , depth= 2 , step cost= 5 , total_cost= 12
#
# step 3
# [[2 3 6]
#  [1 7 5]
#  [4 0 8]]
# action= right , depth= 3 , step cost= 8 , total_cost= 20
#
# step 4
# [[2 3 6]
#  [1 0 5]
#  [4 7 8]]
# action= down , depth= 4 , step cost= 7 , total_cost= 27
#
# step 5
# [[2 3 6]
#  [1 5 0]
#  [4 7 8]]
# action= left , depth= 5 , step cost= 5 , total_cost= 32
#
# step 6
# [[2 3 0]
#  [1 5 6]
#  [4 7 8]]
# action= down , depth= 6 , step cost= 6 , total_cost= 38
#
# step 7
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 7 , step cost= 3 , total_cost= 41
#
# step 8
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 8 , step cost= 2 , total_cost= 43
#
# step 9
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
# action= up , depth= 9 , step cost= 1 , total_cost= 44
#
# step 10
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# action= up , depth= 10 , step cost= 4 , total_cost= 48
#
# step 11
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# action= left , depth= 11 , step cost= 7 , total_cost= 55
#
# step 12
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= left , depth= 12 , step cost= 8 , total_cost= 63
#
# Nodes Poped 2141
# Max Fringe Size 1331
# 'Search Complete'

# %%
# search based on path cost, using priority queue
root_node.uniform_cost_search_BFS(goal_state)
# Out:
# step 0
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 3 6]
#  [1 7 0]
#  [4 8 5]]
# action= left , depth= 1 , step cost= 7 , total_cost= 7
#
# step 2
# [[2 3 6]
#  [1 7 5]
#  [4 8 0]]
# action= up , depth= 2 , step cost= 5 , total_cost= 12
#
# step 3
# [[2 3 6]
#  [1 7 5]
#  [4 0 8]]
# action= right , depth= 3 , step cost= 8 , total_cost= 20
#
# step 4
# [[2 3 6]
#  [1 0 5]
#  [4 7 8]]
# action= down , depth= 4 , step cost= 7 , total_cost= 27
#
# step 5
# [[2 3 6]
#  [1 5 0]
#  [4 7 8]]
# action= left , depth= 5 , step cost= 5 , total_cost= 32
#
# step 6
# [[2 3 0]
#  [1 5 6]
#  [4 7 8]]
# action= down , depth= 6 , step cost= 6 , total_cost= 38
#
# step 7
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 7 , step cost= 3 , total_cost= 41
#
# step 8
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 8 , step cost= 2 , total_cost= 43
#
# step 9
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
# action= up , depth= 9 , step cost= 1 , total_cost= 44
#
# step 10
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# action= up , depth= 10 , step cost= 4 , total_cost= 48
#
# step 11
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# action= left , depth= 11 , step cost= 7 , total_cost= 55
#
# step 12
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= left , depth= 12 , step cost= 8 , total_cost= 63
#
# Nodes Poped 7144
# Max Fringe Size 4208
# 'Search Completed'

# %%
# perform DFS one level deeper at a time, using looping stack
root_node.iterative_deepening_DFS(goal_state)
# Out:
# what is the dept limit: 15
# step 0
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 3 6]
#  [1 7 0]
#  [4 8 5]]
# action= left , depth= 1 , step cost= 7 , total_cost= 7
#
# step 2
# [[2 3 6]
#  [1 7 5]
#  [4 8 0]]
# action= up , depth= 2 , step cost= 5 , total_cost= 12
#
# step 3
# [[2 3 6]
#  [1 7 5]
#  [4 0 8]]
# action= right , depth= 3 , step cost= 8 , total_cost= 20
#
# step 4
# [[2 3 6]
#  [1 0 5]
#  [4 7 8]]
# action= down , depth= 4 , step cost= 7 , total_cost= 27
#
# step 5
# [[2 3 6]
#  [1 5 0]
#  [4 7 8]]
# action= left , depth= 5 , step cost= 5 , total_cost= 32
#
# step 6
# [[2 3 0]
#  [1 5 6]
#  [4 7 8]]
# action= down , depth= 6 , step cost= 6 , total_cost= 38
#
# step 7
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 7 , step cost= 3 , total_cost= 41
#
# step 8
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 8 , step cost= 2 , total_cost= 43
#
# step 9
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
# action= up , depth= 9 , step cost= 1 , total_cost= 44
#
# step 10
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# action= up , depth= 10 , step cost= 4 , total_cost= 48
#
# step 11
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# action= left , depth= 11 , step cost= 7 , total_cost= 55
#
# step 12
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= left , depth= 12 , step cost= 8 , total_cost= 63
#
# Nodes Poped 4584
# Max Fringe Size 14
# 'Search Complete'

# %%
# search based on manhattan distance as the heuristic cost
root_node.greedy_search(goal_state)
# Out:
# step 0
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 3 6]
#  [1 7 0]
#  [4 8 5]]
# action= left , depth= 1 , step cost= 7 , total_cost= 20
#
# step 2
# [[2 3 0]
#  [1 7 6]
#  [4 8 5]]
# action= down , depth= 2 , step cost= 6 , total_cost= 25
#
# step 3
# [[2 0 3]
#  [1 7 6]
#  [4 8 5]]
# action= right , depth= 3 , step cost= 3 , total_cost= 27
#
# step 4
# [[0 2 3]
#  [1 7 6]
#  [4 8 5]]
# action= right , depth= 4 , step cost= 2 , total_cost= 28
#
# step 5
# [[1 2 3]
#  [0 7 6]
#  [4 8 5]]
# action= up , depth= 5 , step cost= 1 , total_cost= 28
#
# step 6
# [[1 2 3]
#  [4 7 6]
#  [0 8 5]]
# action= up , depth= 6 , step cost= 4 , total_cost= 31
#
# step 7
# [[1 2 3]
#  [4 7 6]
#  [8 0 5]]
# action= left , depth= 7 , step cost= 8 , total_cost= 38
#
# step 8
# [[1 2 3]
#  [4 0 6]
#  [8 7 5]]
# action= down , depth= 8 , step cost= 7 , total_cost= 44
#
# step 9
# [[1 2 3]
#  [0 4 6]
#  [8 7 5]]
# action= right , depth= 9 , step cost= 4 , total_cost= 47
#
# step 10
# [[1 2 3]
#  [8 4 6]
#  [0 7 5]]
# action= up , depth= 10 , step cost= 8 , total_cost= 54
#
# step 11
# [[1 2 3]
#  [8 4 6]
#  [7 0 5]]
# action= left , depth= 11 , step cost= 7 , total_cost= 60
#
# step 12
# [[1 2 3]
#  [8 4 6]
#  [7 5 0]]
# action= left , depth= 12 , step cost= 5 , total_cost= 66
#
# step 13
# [[1 2 3]
#  [8 4 0]
#  [7 5 6]]
# action= down , depth= 13 , step cost= 6 , total_cost= 71
#
# step 14
# [[1 2 3]
#  [8 0 4]
#  [7 5 6]]
# action= right , depth= 14 , step cost= 4 , total_cost= 74
#
# step 15
# [[1 2 3]
#  [8 5 4]
#  [7 0 6]]
# action= up , depth= 15 , step cost= 5 , total_cost= 80
#
# step 16
# [[1 2 3]
#  [8 5 4]
#  [7 6 0]]
# action= left , depth= 16 , step cost= 6 , total_cost= 85
#
# step 17
# [[1 2 3]
#  [8 5 0]
#  [7 6 4]]
# action= down , depth= 17 , step cost= 4 , total_cost= 90
#
# step 18
# [[1 2 3]
#  [8 0 5]
#  [7 6 4]]
# action= right , depth= 18 , step cost= 5 , total_cost= 94
#
# step 19
# [[1 2 3]
#  [0 8 5]
#  [7 6 4]]
# action= right , depth= 19 , step cost= 8 , total_cost= 103
#
# step 20
# [[1 2 3]
#  [7 8 5]
#  [0 6 4]]
# action= up , depth= 20 , step cost= 7 , total_cost= 111
#
# step 21
# [[1 2 3]
#  [7 8 5]
#  [6 0 4]]
# action= left , depth= 21 , step cost= 6 , total_cost= 118
#
# step 22
# [[1 2 3]
#  [7 8 5]
#  [6 4 0]]
# action= left , depth= 22 , step cost= 4 , total_cost= 123
#
# step 23
# [[1 2 3]
#  [7 8 0]
#  [6 4 5]]
# action= down , depth= 23 , step cost= 5 , total_cost= 127
#
# step 24
# [[1 2 3]
#  [7 0 8]
#  [6 4 5]]
# action= right , depth= 24 , step cost= 8 , total_cost= 136
#
# step 25
# [[1 2 3]
#  [7 4 8]
#  [6 0 5]]
# action= up , depth= 25 , step cost= 4 , total_cost= 139
#
# step 26
# [[1 2 3]
#  [7 4 8]
#  [0 6 5]]
# action= right , depth= 26 , step cost= 6 , total_cost= 144
#
# step 27
# [[1 2 3]
#  [0 4 8]
#  [7 6 5]]
# action= down , depth= 27 , step cost= 7 , total_cost= 150
#
# step 28
# [[1 2 3]
#  [4 0 8]
#  [7 6 5]]
# action= left , depth= 28 , step cost= 4 , total_cost= 155
#
# step 29
# [[1 2 3]
#  [4 8 0]
#  [7 6 5]]
# action= left , depth= 29 , step cost= 8 , total_cost= 162
#
# step 30
# [[1 2 3]
#  [4 8 5]
#  [7 6 0]]
# action= up , depth= 30 , step cost= 5 , total_cost= 168
#
# step 31
# [[1 2 3]
#  [4 8 5]
#  [7 0 6]]
# action= right , depth= 31 , step cost= 6 , total_cost= 175
#
# step 32
# [[1 2 3]
#  [4 0 5]
#  [7 8 6]]
# action= down , depth= 32 , step cost= 8 , total_cost= 184
#
# step 33
# [[1 2 3]
#  [4 5 0]
#  [7 8 6]]
# action= left , depth= 33 , step cost= 5 , total_cost= 190
#
# step 34
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= up , depth= 34 , step cost= 6 , total_cost= 197
#
# Agents Poped 1321
# Max Fringe Size 893
# 'Search Complete'

# %%
# A*3 search based on path cost+heuristic cost, using priority queue
# No.1 fast
root_node.a_star_search(goal_state,heuristic_function = 'fair_manhattan')
# Out:
# step 0
# [[2 3 6]
#  [1 0 7]
#  [4 8 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 3 6]
#  [1 7 0]
#  [4 8 5]]
# action= left , depth= 1 , step cost= 7 , total_cost= 14
#
# step 2
# [[2 3 6]
#  [1 7 5]
#  [4 8 0]]
# action= up , depth= 2 , step cost= 5 , total_cost= 16
#
# step 3
# [[2 3 6]
#  [1 7 5]
#  [4 0 8]]
# action= right , depth= 3 , step cost= 8 , total_cost= 18
#
# step 4
# [[2 3 6]
#  [1 0 5]
#  [4 7 8]]
# action= down , depth= 4 , step cost= 7 , total_cost= 18
#
# step 5
# [[2 3 6]
#  [1 5 0]
#  [4 7 8]]
# action= left , depth= 5 , step cost= 5 , total_cost= 20
#
# step 6
# [[2 3 0]
#  [1 5 6]
#  [4 7 8]]
# action= down , depth= 6 , step cost= 6 , total_cost= 20
#
# step 7
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 7 , step cost= 3 , total_cost= 20
#
# step 8
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 8 , step cost= 2 , total_cost= 20
#
# step 9
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
# action= up , depth= 9 , step cost= 1 , total_cost= 20
#
# step 10
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# action= up , depth= 10 , step cost= 4 , total_cost= 20
#
# step 11
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# action= left , depth= 11 , step cost= 7 , total_cost= 20
#
# step 12
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= left , depth= 12 , step cost= 8 , total_cost= 20
#
# Agents Poped 593
# Max Fringe Size 390
# 'Search Complete'

# %%
# search as far as possible along each branch before backtracking, using stack
root_node.depth_first_search(goal_state)
# Out:
# Streaming output truncated to the last 5000 lines.
# step 100848
# [[0 6 3]
#  [1 8 4]
#  [5 7 2]]
# action= down , depth= 100848 , step cost= 1 , total_cost= 454005
#
# step 100849
# [[6 0 3]
#  [1 8 4]
#  [5 7 2]]
# action= left , depth= 100849 , step cost= 6 , total_cost= 454011
#
# step 100850
# [[6 3 0]
#  [1 8 4]
#  [5 7 2]]
# action= left , depth= 100850 , step cost= 3 , total_cost= 454014
#
# step 100851
# [[6 3 4]
#  [1 8 0]
#  [5 7 2]]
# action= up , depth= 100851 , step cost= 4 , total_cost= 454018
#
# step 100852
# [[6 3 4]
#  [1 0 8]
#  [5 7 2]]
# action= right , depth= 100852 , step cost= 8 , total_cost= 454026
#
# step 100853
# [[6 3 4]
#  [0 1 8]
#  [5 7 2]]
# action= right , depth= 100853 , step cost= 1 , total_cost= 454027
#
# step 100854
# [[0 3 4]
#  [6 1 8]
#  [5 7 2]]
# action= down , depth= 100854 , step cost= 6 , total_cost= 454033
#
# step 100855
# [[3 0 4]
#  [6 1 8]
#  [5 7 2]]
# action= left , depth= 100855 , step cost= 3 , total_cost= 454036
#
# step 100856
# [[3 4 0]
#  [6 1 8]
#  [5 7 2]]
# action= left , depth= 100856 , step cost= 4 , total_cost= 454040
#
# step 100857
# [[3 4 8]
#  [6 1 0]
#  [5 7 2]]
# action= up , depth= 100857 , step cost= 8 , total_cost= 454048
#
# step 100858
# [[3 4 8]
#  [6 0 1]
#  [5 7 2]]
# action= right , depth= 100858 , step cost= 1 , total_cost= 454049
#
# step 100859
# [[3 4 8]
#  [0 6 1]
#  [5 7 2]]
# action= right , depth= 100859 , step cost= 6 , total_cost= 454055
#
# step 100860
# [[0 4 8]
#  [3 6 1]
#  [5 7 2]]
# action= down , depth= 100860 , step cost= 3 , total_cost= 454058
#
# step 100861
# [[4 0 8]
#  [3 6 1]
#  [5 7 2]]
# action= left , depth= 100861 , step cost= 4 , total_cost= 454062
#
# step 100862
# [[4 8 0]
#  [3 6 1]
#  [5 7 2]]
# action= left , depth= 100862 , step cost= 8 , total_cost= 454070
#
# step 100863
# [[4 8 1]
#  [3 6 0]
#  [5 7 2]]
# action= up , depth= 100863 , step cost= 1 , total_cost= 454071
#
# step 100864
# [[4 8 1]
#  [3 0 6]
#  [5 7 2]]
# action= right , depth= 100864 , step cost= 6 , total_cost= 454077
#
# step 100865
# [[4 8 1]
#  [0 3 6]
#  [5 7 2]]
# action= right , depth= 100865 , step cost= 3 , total_cost= 454080
#
# step 100866
# [[0 8 1]
#  [4 3 6]
#  [5 7 2]]
# action= down , depth= 100866 , step cost= 4 , total_cost= 454084
#
# step 100867
# [[8 0 1]
#  [4 3 6]
#  [5 7 2]]
# action= left , depth= 100867 , step cost= 8 , total_cost= 454092
#
# step 100868
# [[8 1 0]
#  [4 3 6]
#  [5 7 2]]
# action= left , depth= 100868 , step cost= 1 , total_cost= 454093
#
# step 100869
# [[8 1 6]
#  [4 3 0]
#  [5 7 2]]
# action= up , depth= 100869 , step cost= 6 , total_cost= 454099
#
# step 100870
# [[8 1 6]
#  [4 0 3]
#  [5 7 2]]
# action= right , depth= 100870 , step cost= 3 , total_cost= 454102
#
# step 100871
# [[8 0 6]
#  [4 1 3]
#  [5 7 2]]
# action= down , depth= 100871 , step cost= 1 , total_cost= 454103
#
# step 100872
# [[0 8 6]
#  [4 1 3]
#  [5 7 2]]
# action= right , depth= 100872 , step cost= 8 , total_cost= 454111
#
# step 100873
# [[4 8 6]
#  [0 1 3]
#  [5 7 2]]
# action= up , depth= 100873 , step cost= 4 , total_cost= 454115
#
# step 100874
# [[4 8 6]
#  [1 0 3]
#  [5 7 2]]
# action= left , depth= 100874 , step cost= 1 , total_cost= 454116
#
# step 100875
# [[4 8 6]
#  [1 3 0]
#  [5 7 2]]
# action= left , depth= 100875 , step cost= 3 , total_cost= 454119
#
# step 100876
# [[4 8 0]
#  [1 3 6]
#  [5 7 2]]
# action= down , depth= 100876 , step cost= 6 , total_cost= 454125
#
# step 100877
# [[4 0 8]
#  [1 3 6]
#  [5 7 2]]
# action= right , depth= 100877 , step cost= 8 , total_cost= 454133
#
# step 100878
# [[0 4 8]
#  [1 3 6]
#  [5 7 2]]
# action= right , depth= 100878 , step cost= 4 , total_cost= 454137
#
# step 100879
# [[1 4 8]
#  [0 3 6]
#  [5 7 2]]
# action= up , depth= 100879 , step cost= 1 , total_cost= 454138
#
# step 100880
# [[1 4 8]
#  [3 0 6]
#  [5 7 2]]
# action= left , depth= 100880 , step cost= 3 , total_cost= 454141
#
# step 100881
# [[1 4 8]
#  [3 6 0]
#  [5 7 2]]
# action= left , depth= 100881 , step cost= 6 , total_cost= 454147
#
# step 100882
# [[1 4 0]
#  [3 6 8]
#  [5 7 2]]
# action= down , depth= 100882 , step cost= 8 , total_cost= 454155
#
# step 100883
# [[1 0 4]
#  [3 6 8]
#  [5 7 2]]
# action= right , depth= 100883 , step cost= 4 , total_cost= 454159
#
# step 100884
# [[0 1 4]
#  [3 6 8]
#  [5 7 2]]
# action= right , depth= 100884 , step cost= 1 , total_cost= 454160
#
# step 100885
# [[3 1 4]
#  [0 6 8]
#  [5 7 2]]
# action= up , depth= 100885 , step cost= 3 , total_cost= 454163
#
# step 100886
# [[3 1 4]
#  [6 0 8]
#  [5 7 2]]
# action= left , depth= 100886 , step cost= 6 , total_cost= 454169
#
# step 100887
# [[3 1 4]
#  [6 8 0]
#  [5 7 2]]
# action= left , depth= 100887 , step cost= 8 , total_cost= 454177
#
# step 100888
# [[3 1 4]
#  [6 8 2]
#  [5 7 0]]
# action= up , depth= 100888 , step cost= 2 , total_cost= 454179
#
# step 100889
# [[3 1 4]
#  [6 8 2]
#  [5 0 7]]
# action= right , depth= 100889 , step cost= 7 , total_cost= 454186
#
# step 100890
# [[3 1 4]
#  [6 8 2]
#  [0 5 7]]
# action= right , depth= 100890 , step cost= 5 , total_cost= 454191
#
# step 100891
# [[3 1 4]
#  [0 8 2]
#  [6 5 7]]
# action= down , depth= 100891 , step cost= 6 , total_cost= 454197
#
# step 100892
# [[3 1 4]
#  [8 0 2]
#  [6 5 7]]
# action= left , depth= 100892 , step cost= 8 , total_cost= 454205
#
# step 100893
# [[3 1 4]
#  [8 2 0]
#  [6 5 7]]
# action= left , depth= 100893 , step cost= 2 , total_cost= 454207
#
# step 100894
# [[3 1 0]
#  [8 2 4]
#  [6 5 7]]
# action= down , depth= 100894 , step cost= 4 , total_cost= 454211
#
# step 100895
# [[3 0 1]
#  [8 2 4]
#  [6 5 7]]
# action= right , depth= 100895 , step cost= 1 , total_cost= 454212
#
# step 100896
# [[0 3 1]
#  [8 2 4]
#  [6 5 7]]
# action= right , depth= 100896 , step cost= 3 , total_cost= 454215
#
# step 100897
# [[8 3 1]
#  [0 2 4]
#  [6 5 7]]
# action= up , depth= 100897 , step cost= 8 , total_cost= 454223
#
# step 100898
# [[8 3 1]
#  [2 0 4]
#  [6 5 7]]
# action= left , depth= 100898 , step cost= 2 , total_cost= 454225
#
# step 100899
# [[8 3 1]
#  [2 4 0]
#  [6 5 7]]
# action= left , depth= 100899 , step cost= 4 , total_cost= 454229
#
# step 100900
# [[8 3 0]
#  [2 4 1]
#  [6 5 7]]
# action= down , depth= 100900 , step cost= 1 , total_cost= 454230
#
# step 100901
# [[8 0 3]
#  [2 4 1]
#  [6 5 7]]
# action= right , depth= 100901 , step cost= 3 , total_cost= 454233
#
# step 100902
# [[0 8 3]
#  [2 4 1]
#  [6 5 7]]
# action= right , depth= 100902 , step cost= 8 , total_cost= 454241
#
# step 100903
# [[2 8 3]
#  [0 4 1]
#  [6 5 7]]
# action= up , depth= 100903 , step cost= 2 , total_cost= 454243
#
# step 100904
# [[2 8 3]
#  [4 0 1]
#  [6 5 7]]
# action= left , depth= 100904 , step cost= 4 , total_cost= 454247
#
# step 100905
# [[2 8 3]
#  [4 1 0]
#  [6 5 7]]
# action= left , depth= 100905 , step cost= 1 , total_cost= 454248
#
# step 100906
# [[2 8 0]
#  [4 1 3]
#  [6 5 7]]
# action= down , depth= 100906 , step cost= 3 , total_cost= 454251
#
# step 100907
# [[2 0 8]
#  [4 1 3]
#  [6 5 7]]
# action= right , depth= 100907 , step cost= 8 , total_cost= 454259
#
# step 100908
# [[0 2 8]
#  [4 1 3]
#  [6 5 7]]
# action= right , depth= 100908 , step cost= 2 , total_cost= 454261
#
# step 100909
# [[4 2 8]
#  [0 1 3]
#  [6 5 7]]
# action= up , depth= 100909 , step cost= 4 , total_cost= 454265
#
# step 100910
# [[4 2 8]
#  [1 0 3]
#  [6 5 7]]
# action= left , depth= 100910 , step cost= 1 , total_cost= 454266
#
# step 100911
# [[4 2 8]
#  [1 3 0]
#  [6 5 7]]
# action= left , depth= 100911 , step cost= 3 , total_cost= 454269
#
# step 100912
# [[4 2 0]
#  [1 3 8]
#  [6 5 7]]
# action= down , depth= 100912 , step cost= 8 , total_cost= 454277
#
# step 100913
# [[4 0 2]
#  [1 3 8]
#  [6 5 7]]
# action= right , depth= 100913 , step cost= 2 , total_cost= 454279
#
# step 100914
# [[0 4 2]
#  [1 3 8]
#  [6 5 7]]
# action= right , depth= 100914 , step cost= 4 , total_cost= 454283
#
# step 100915
# [[1 4 2]
#  [0 3 8]
#  [6 5 7]]
# action= up , depth= 100915 , step cost= 1 , total_cost= 454284
#
# step 100916
# [[1 4 2]
#  [3 0 8]
#  [6 5 7]]
# action= left , depth= 100916 , step cost= 3 , total_cost= 454287
#
# step 100917
# [[1 4 2]
#  [3 8 0]
#  [6 5 7]]
# action= left , depth= 100917 , step cost= 8 , total_cost= 454295
#
# step 100918
# [[1 4 2]
#  [3 8 7]
#  [6 5 0]]
# action= up , depth= 100918 , step cost= 7 , total_cost= 454302
#
# step 100919
# [[1 4 2]
#  [3 8 7]
#  [6 0 5]]
# action= right , depth= 100919 , step cost= 5 , total_cost= 454307
#
# step 100920
# [[1 4 2]
#  [3 0 7]
#  [6 8 5]]
# action= down , depth= 100920 , step cost= 8 , total_cost= 454315
#
# step 100921
# [[1 4 2]
#  [0 3 7]
#  [6 8 5]]
# action= right , depth= 100921 , step cost= 3 , total_cost= 454318
#
# step 100922
# [[0 4 2]
#  [1 3 7]
#  [6 8 5]]
# action= down , depth= 100922 , step cost= 1 , total_cost= 454319
#
# step 100923
# [[4 0 2]
#  [1 3 7]
#  [6 8 5]]
# action= left , depth= 100923 , step cost= 4 , total_cost= 454323
#
# step 100924
# [[4 2 0]
#  [1 3 7]
#  [6 8 5]]
# action= left , depth= 100924 , step cost= 2 , total_cost= 454325
#
# step 100925
# [[4 2 7]
#  [1 3 0]
#  [6 8 5]]
# action= up , depth= 100925 , step cost= 7 , total_cost= 454332
#
# step 100926
# [[4 2 7]
#  [1 0 3]
#  [6 8 5]]
# action= right , depth= 100926 , step cost= 3 , total_cost= 454335
#
# step 100927
# [[4 2 7]
#  [0 1 3]
#  [6 8 5]]
# action= right , depth= 100927 , step cost= 1 , total_cost= 454336
#
# step 100928
# [[0 2 7]
#  [4 1 3]
#  [6 8 5]]
# action= down , depth= 100928 , step cost= 4 , total_cost= 454340
#
# step 100929
# [[2 0 7]
#  [4 1 3]
#  [6 8 5]]
# action= left , depth= 100929 , step cost= 2 , total_cost= 454342
#
# step 100930
# [[2 7 0]
#  [4 1 3]
#  [6 8 5]]
# action= left , depth= 100930 , step cost= 7 , total_cost= 454349
#
# step 100931
# [[2 7 3]
#  [4 1 0]
#  [6 8 5]]
# action= up , depth= 100931 , step cost= 3 , total_cost= 454352
#
# step 100932
# [[2 7 3]
#  [4 0 1]
#  [6 8 5]]
# action= right , depth= 100932 , step cost= 1 , total_cost= 454353
#
# step 100933
# [[2 7 3]
#  [0 4 1]
#  [6 8 5]]
# action= right , depth= 100933 , step cost= 4 , total_cost= 454357
#
# step 100934
# [[0 7 3]
#  [2 4 1]
#  [6 8 5]]
# action= down , depth= 100934 , step cost= 2 , total_cost= 454359
#
# step 100935
# [[7 0 3]
#  [2 4 1]
#  [6 8 5]]
# action= left , depth= 100935 , step cost= 7 , total_cost= 454366
#
# step 100936
# [[7 3 0]
#  [2 4 1]
#  [6 8 5]]
# action= left , depth= 100936 , step cost= 3 , total_cost= 454369
#
# step 100937
# [[7 3 1]
#  [2 4 0]
#  [6 8 5]]
# action= up , depth= 100937 , step cost= 1 , total_cost= 454370
#
# step 100938
# [[7 3 1]
#  [2 0 4]
#  [6 8 5]]
# action= right , depth= 100938 , step cost= 4 , total_cost= 454374
#
# step 100939
# [[7 3 1]
#  [0 2 4]
#  [6 8 5]]
# action= right , depth= 100939 , step cost= 2 , total_cost= 454376
#
# step 100940
# [[0 3 1]
#  [7 2 4]
#  [6 8 5]]
# action= down , depth= 100940 , step cost= 7 , total_cost= 454383
#
# step 100941
# [[3 0 1]
#  [7 2 4]
#  [6 8 5]]
# action= left , depth= 100941 , step cost= 3 , total_cost= 454386
#
# step 100942
# [[3 1 0]
#  [7 2 4]
#  [6 8 5]]
# action= left , depth= 100942 , step cost= 1 , total_cost= 454387
#
# step 100943
# [[3 1 4]
#  [7 2 0]
#  [6 8 5]]
# action= up , depth= 100943 , step cost= 4 , total_cost= 454391
#
# step 100944
# [[3 1 4]
#  [7 0 2]
#  [6 8 5]]
# action= right , depth= 100944 , step cost= 2 , total_cost= 454393
#
# step 100945
# [[3 1 4]
#  [0 7 2]
#  [6 8 5]]
# action= right , depth= 100945 , step cost= 7 , total_cost= 454400
#
# step 100946
# [[0 1 4]
#  [3 7 2]
#  [6 8 5]]
# action= down , depth= 100946 , step cost= 3 , total_cost= 454403
#
# step 100947
# [[1 0 4]
#  [3 7 2]
#  [6 8 5]]
# action= left , depth= 100947 , step cost= 1 , total_cost= 454404
#
# step 100948
# [[1 7 4]
#  [3 0 2]
#  [6 8 5]]
# action= up , depth= 100948 , step cost= 7 , total_cost= 454411
#
# step 100949
# [[1 7 4]
#  [0 3 2]
#  [6 8 5]]
# action= right , depth= 100949 , step cost= 3 , total_cost= 454414
#
# step 100950
# [[0 7 4]
#  [1 3 2]
#  [6 8 5]]
# action= down , depth= 100950 , step cost= 1 , total_cost= 454415
#
# step 100951
# [[7 0 4]
#  [1 3 2]
#  [6 8 5]]
# action= left , depth= 100951 , step cost= 7 , total_cost= 454422
#
# step 100952
# [[7 4 0]
#  [1 3 2]
#  [6 8 5]]
# action= left , depth= 100952 , step cost= 4 , total_cost= 454426
#
# step 100953
# [[7 4 2]
#  [1 3 0]
#  [6 8 5]]
# action= up , depth= 100953 , step cost= 2 , total_cost= 454428
#
# step 100954
# [[7 4 2]
#  [1 0 3]
#  [6 8 5]]
# action= right , depth= 100954 , step cost= 3 , total_cost= 454431
#
# step 100955
# [[7 4 2]
#  [0 1 3]
#  [6 8 5]]
# action= right , depth= 100955 , step cost= 1 , total_cost= 454432
#
# step 100956
# [[0 4 2]
#  [7 1 3]
#  [6 8 5]]
# action= down , depth= 100956 , step cost= 7 , total_cost= 454439
#
# step 100957
# [[4 0 2]
#  [7 1 3]
#  [6 8 5]]
# action= left , depth= 100957 , step cost= 4 , total_cost= 454443
#
# step 100958
# [[4 2 0]
#  [7 1 3]
#  [6 8 5]]
# action= left , depth= 100958 , step cost= 2 , total_cost= 454445
#
# step 100959
# [[4 2 3]
#  [7 1 0]
#  [6 8 5]]
# action= up , depth= 100959 , step cost= 3 , total_cost= 454448
#
# step 100960
# [[4 2 3]
#  [7 0 1]
#  [6 8 5]]
# action= right , depth= 100960 , step cost= 1 , total_cost= 454449
#
# step 100961
# [[4 2 3]
#  [0 7 1]
#  [6 8 5]]
# action= right , depth= 100961 , step cost= 7 , total_cost= 454456
#
# step 100962
# [[0 2 3]
#  [4 7 1]
#  [6 8 5]]
# action= down , depth= 100962 , step cost= 4 , total_cost= 454460
#
# step 100963
# [[2 0 3]
#  [4 7 1]
#  [6 8 5]]
# action= left , depth= 100963 , step cost= 2 , total_cost= 454462
#
# step 100964
# [[2 3 0]
#  [4 7 1]
#  [6 8 5]]
# action= left , depth= 100964 , step cost= 3 , total_cost= 454465
#
# step 100965
# [[2 3 1]
#  [4 7 0]
#  [6 8 5]]
# action= up , depth= 100965 , step cost= 1 , total_cost= 454466
#
# step 100966
# [[2 3 1]
#  [4 0 7]
#  [6 8 5]]
# action= right , depth= 100966 , step cost= 7 , total_cost= 454473
#
# step 100967
# [[2 0 1]
#  [4 3 7]
#  [6 8 5]]
# action= down , depth= 100967 , step cost= 3 , total_cost= 454476
#
# step 100968
# [[0 2 1]
#  [4 3 7]
#  [6 8 5]]
# action= right , depth= 100968 , step cost= 2 , total_cost= 454478
#
# step 100969
# [[4 2 1]
#  [0 3 7]
#  [6 8 5]]
# action= up , depth= 100969 , step cost= 4 , total_cost= 454482
#
# step 100970
# [[4 2 1]
#  [3 0 7]
#  [6 8 5]]
# action= left , depth= 100970 , step cost= 3 , total_cost= 454485
#
# step 100971
# [[4 2 1]
#  [3 7 0]
#  [6 8 5]]
# action= left , depth= 100971 , step cost= 7 , total_cost= 454492
#
# step 100972
# [[4 2 0]
#  [3 7 1]
#  [6 8 5]]
# action= down , depth= 100972 , step cost= 1 , total_cost= 454493
#
# step 100973
# [[4 0 2]
#  [3 7 1]
#  [6 8 5]]
# action= right , depth= 100973 , step cost= 2 , total_cost= 454495
#
# step 100974
# [[0 4 2]
#  [3 7 1]
#  [6 8 5]]
# action= right , depth= 100974 , step cost= 4 , total_cost= 454499
#
# step 100975
# [[3 4 2]
#  [0 7 1]
#  [6 8 5]]
# action= up , depth= 100975 , step cost= 3 , total_cost= 454502
#
# step 100976
# [[3 4 2]
#  [7 0 1]
#  [6 8 5]]
# action= left , depth= 100976 , step cost= 7 , total_cost= 454509
#
# step 100977
# [[3 4 2]
#  [7 1 0]
#  [6 8 5]]
# action= left , depth= 100977 , step cost= 1 , total_cost= 454510
#
# step 100978
# [[3 4 0]
#  [7 1 2]
#  [6 8 5]]
# action= down , depth= 100978 , step cost= 2 , total_cost= 454512
#
# step 100979
# [[3 0 4]
#  [7 1 2]
#  [6 8 5]]
# action= right , depth= 100979 , step cost= 4 , total_cost= 454516
#
# step 100980
# [[0 3 4]
#  [7 1 2]
#  [6 8 5]]
# action= right , depth= 100980 , step cost= 3 , total_cost= 454519
#
# step 100981
# [[7 3 4]
#  [0 1 2]
#  [6 8 5]]
# action= up , depth= 100981 , step cost= 7 , total_cost= 454526
#
# step 100982
# [[7 3 4]
#  [1 0 2]
#  [6 8 5]]
# action= left , depth= 100982 , step cost= 1 , total_cost= 454527
#
# step 100983
# [[7 3 4]
#  [1 2 0]
#  [6 8 5]]
# action= left , depth= 100983 , step cost= 2 , total_cost= 454529
#
# step 100984
# [[7 3 0]
#  [1 2 4]
#  [6 8 5]]
# action= down , depth= 100984 , step cost= 4 , total_cost= 454533
#
# step 100985
# [[7 0 3]
#  [1 2 4]
#  [6 8 5]]
# action= right , depth= 100985 , step cost= 3 , total_cost= 454536
#
# step 100986
# [[0 7 3]
#  [1 2 4]
#  [6 8 5]]
# action= right , depth= 100986 , step cost= 7 , total_cost= 454543
#
# step 100987
# [[1 7 3]
#  [0 2 4]
#  [6 8 5]]
# action= up , depth= 100987 , step cost= 1 , total_cost= 454544
#
# step 100988
# [[1 7 3]
#  [2 0 4]
#  [6 8 5]]
# action= left , depth= 100988 , step cost= 2 , total_cost= 454546
#
# step 100989
# [[1 7 3]
#  [2 4 0]
#  [6 8 5]]
# action= left , depth= 100989 , step cost= 4 , total_cost= 454550
#
# step 100990
# [[1 7 3]
#  [2 4 5]
#  [6 8 0]]
# action= up , depth= 100990 , step cost= 5 , total_cost= 454555
#
# step 100991
# [[1 7 3]
#  [2 4 5]
#  [6 0 8]]
# action= right , depth= 100991 , step cost= 8 , total_cost= 454563
#
# step 100992
# [[1 7 3]
#  [2 0 5]
#  [6 4 8]]
# action= down , depth= 100992 , step cost= 4 , total_cost= 454567
#
# step 100993
# [[1 7 3]
#  [0 2 5]
#  [6 4 8]]
# action= right , depth= 100993 , step cost= 2 , total_cost= 454569
#
# step 100994
# [[0 7 3]
#  [1 2 5]
#  [6 4 8]]
# action= down , depth= 100994 , step cost= 1 , total_cost= 454570
#
# step 100995
# [[7 0 3]
#  [1 2 5]
#  [6 4 8]]
# action= left , depth= 100995 , step cost= 7 , total_cost= 454577
#
# step 100996
# [[7 3 0]
#  [1 2 5]
#  [6 4 8]]
# action= left , depth= 100996 , step cost= 3 , total_cost= 454580
#
# step 100997
# [[7 3 5]
#  [1 2 0]
#  [6 4 8]]
# action= up , depth= 100997 , step cost= 5 , total_cost= 454585
#
# step 100998
# [[7 3 5]
#  [1 0 2]
#  [6 4 8]]
# action= right , depth= 100998 , step cost= 2 , total_cost= 454587
#
# step 100999
# [[7 3 5]
#  [0 1 2]
#  [6 4 8]]
# action= right , depth= 100999 , step cost= 1 , total_cost= 454588
#
# step 101000
# [[0 3 5]
#  [7 1 2]
#  [6 4 8]]
# action= down , depth= 101000 , step cost= 7 , total_cost= 454595
#
# step 101001
# [[3 0 5]
#  [7 1 2]
#  [6 4 8]]
# action= left , depth= 101001 , step cost= 3 , total_cost= 454598
#
# step 101002
# [[3 5 0]
#  [7 1 2]
#  [6 4 8]]
# action= left , depth= 101002 , step cost= 5 , total_cost= 454603
#
# step 101003
# [[3 5 2]
#  [7 1 0]
#  [6 4 8]]
# action= up , depth= 101003 , step cost= 2 , total_cost= 454605
#
# step 101004
# [[3 5 2]
#  [7 0 1]
#  [6 4 8]]
# action= right , depth= 101004 , step cost= 1 , total_cost= 454606
#
# step 101005
# [[3 5 2]
#  [0 7 1]
#  [6 4 8]]
# action= right , depth= 101005 , step cost= 7 , total_cost= 454613
#
# step 101006
# [[0 5 2]
#  [3 7 1]
#  [6 4 8]]
# action= down , depth= 101006 , step cost= 3 , total_cost= 454616
#
# step 101007
# [[5 0 2]
#  [3 7 1]
#  [6 4 8]]
# action= left , depth= 101007 , step cost= 5 , total_cost= 454621
#
# step 101008
# [[5 2 0]
#  [3 7 1]
#  [6 4 8]]
# action= left , depth= 101008 , step cost= 2 , total_cost= 454623
#
# step 101009
# [[5 2 1]
#  [3 7 0]
#  [6 4 8]]
# action= up , depth= 101009 , step cost= 1 , total_cost= 454624
#
# step 101010
# [[5 2 1]
#  [3 0 7]
#  [6 4 8]]
# action= right , depth= 101010 , step cost= 7 , total_cost= 454631
#
# step 101011
# [[5 2 1]
#  [0 3 7]
#  [6 4 8]]
# action= right , depth= 101011 , step cost= 3 , total_cost= 454634
#
# step 101012
# [[0 2 1]
#  [5 3 7]
#  [6 4 8]]
# action= down , depth= 101012 , step cost= 5 , total_cost= 454639
#
# step 101013
# [[2 0 1]
#  [5 3 7]
#  [6 4 8]]
# action= left , depth= 101013 , step cost= 2 , total_cost= 454641
#
# step 101014
# [[2 1 0]
#  [5 3 7]
#  [6 4 8]]
# action= left , depth= 101014 , step cost= 1 , total_cost= 454642
#
# step 101015
# [[2 1 7]
#  [5 3 0]
#  [6 4 8]]
# action= up , depth= 101015 , step cost= 7 , total_cost= 454649
#
# step 101016
# [[2 1 7]
#  [5 0 3]
#  [6 4 8]]
# action= right , depth= 101016 , step cost= 3 , total_cost= 454652
#
# step 101017
# [[2 1 7]
#  [0 5 3]
#  [6 4 8]]
# action= right , depth= 101017 , step cost= 5 , total_cost= 454657
#
# step 101018
# [[0 1 7]
#  [2 5 3]
#  [6 4 8]]
# action= down , depth= 101018 , step cost= 2 , total_cost= 454659
#
# step 101019
# [[1 0 7]
#  [2 5 3]
#  [6 4 8]]
# action= left , depth= 101019 , step cost= 1 , total_cost= 454660
#
# step 101020
# [[1 5 7]
#  [2 0 3]
#  [6 4 8]]
# action= up , depth= 101020 , step cost= 5 , total_cost= 454665
#
# step 101021
# [[1 5 7]
#  [0 2 3]
#  [6 4 8]]
# action= right , depth= 101021 , step cost= 2 , total_cost= 454667
#
# step 101022
# [[0 5 7]
#  [1 2 3]
#  [6 4 8]]
# action= down , depth= 101022 , step cost= 1 , total_cost= 454668
#
# step 101023
# [[5 0 7]
#  [1 2 3]
#  [6 4 8]]
# action= left , depth= 101023 , step cost= 5 , total_cost= 454673
#
# step 101024
# [[5 7 0]
#  [1 2 3]
#  [6 4 8]]
# action= left , depth= 101024 , step cost= 7 , total_cost= 454680
#
# step 101025
# [[5 7 3]
#  [1 2 0]
#  [6 4 8]]
# action= up , depth= 101025 , step cost= 3 , total_cost= 454683
#
# step 101026
# [[5 7 3]
#  [1 0 2]
#  [6 4 8]]
# action= right , depth= 101026 , step cost= 2 , total_cost= 454685
#
# step 101027
# [[5 7 3]
#  [0 1 2]
#  [6 4 8]]
# action= right , depth= 101027 , step cost= 1 , total_cost= 454686
#
# step 101028
# [[0 7 3]
#  [5 1 2]
#  [6 4 8]]
# action= down , depth= 101028 , step cost= 5 , total_cost= 454691
#
# step 101029
# [[7 0 3]
#  [5 1 2]
#  [6 4 8]]
# action= left , depth= 101029 , step cost= 7 , total_cost= 454698
#
# step 101030
# [[7 3 0]
#  [5 1 2]
#  [6 4 8]]
# action= left , depth= 101030 , step cost= 3 , total_cost= 454701
#
# step 101031
# [[7 3 2]
#  [5 1 0]
#  [6 4 8]]
# action= up , depth= 101031 , step cost= 2 , total_cost= 454703
#
# step 101032
# [[7 3 2]
#  [5 0 1]
#  [6 4 8]]
# action= right , depth= 101032 , step cost= 1 , total_cost= 454704
#
# step 101033
# [[7 3 2]
#  [0 5 1]
#  [6 4 8]]
# action= right , depth= 101033 , step cost= 5 , total_cost= 454709
#
# step 101034
# [[0 3 2]
#  [7 5 1]
#  [6 4 8]]
# action= down , depth= 101034 , step cost= 7 , total_cost= 454716
#
# step 101035
# [[3 0 2]
#  [7 5 1]
#  [6 4 8]]
# action= left , depth= 101035 , step cost= 3 , total_cost= 454719
#
# step 101036
# [[3 2 0]
#  [7 5 1]
#  [6 4 8]]
# action= left , depth= 101036 , step cost= 2 , total_cost= 454721
#
# step 101037
# [[3 2 1]
#  [7 5 0]
#  [6 4 8]]
# action= up , depth= 101037 , step cost= 1 , total_cost= 454722
#
# step 101038
# [[3 2 1]
#  [7 0 5]
#  [6 4 8]]
# action= right , depth= 101038 , step cost= 5 , total_cost= 454727
#
# step 101039
# [[3 0 1]
#  [7 2 5]
#  [6 4 8]]
# action= down , depth= 101039 , step cost= 2 , total_cost= 454729
#
# step 101040
# [[0 3 1]
#  [7 2 5]
#  [6 4 8]]
# action= right , depth= 101040 , step cost= 3 , total_cost= 454732
#
# step 101041
# [[7 3 1]
#  [0 2 5]
#  [6 4 8]]
# action= up , depth= 101041 , step cost= 7 , total_cost= 454739
#
# step 101042
# [[7 3 1]
#  [2 0 5]
#  [6 4 8]]
# action= left , depth= 101042 , step cost= 2 , total_cost= 454741
#
# step 101043
# [[7 3 1]
#  [2 5 0]
#  [6 4 8]]
# action= left , depth= 101043 , step cost= 5 , total_cost= 454746
#
# step 101044
# [[7 3 0]
#  [2 5 1]
#  [6 4 8]]
# action= down , depth= 101044 , step cost= 1 , total_cost= 454747
#
# step 101045
# [[7 0 3]
#  [2 5 1]
#  [6 4 8]]
# action= right , depth= 101045 , step cost= 3 , total_cost= 454750
#
# step 101046
# [[0 7 3]
#  [2 5 1]
#  [6 4 8]]
# action= right , depth= 101046 , step cost= 7 , total_cost= 454757
#
# step 101047
# [[2 7 3]
#  [0 5 1]
#  [6 4 8]]
# action= up , depth= 101047 , step cost= 2 , total_cost= 454759
#
# step 101048
# [[2 7 3]
#  [5 0 1]
#  [6 4 8]]
# action= left , depth= 101048 , step cost= 5 , total_cost= 454764
#
# step 101049
# [[2 7 3]
#  [5 1 0]
#  [6 4 8]]
# action= left , depth= 101049 , step cost= 1 , total_cost= 454765
#
# step 101050
# [[2 7 0]
#  [5 1 3]
#  [6 4 8]]
# action= down , depth= 101050 , step cost= 3 , total_cost= 454768
#
# step 101051
# [[2 0 7]
#  [5 1 3]
#  [6 4 8]]
# action= right , depth= 101051 , step cost= 7 , total_cost= 454775
#
# step 101052
# [[0 2 7]
#  [5 1 3]
#  [6 4 8]]
# action= right , depth= 101052 , step cost= 2 , total_cost= 454777
#
# step 101053
# [[5 2 7]
#  [0 1 3]
#  [6 4 8]]
# action= up , depth= 101053 , step cost= 5 , total_cost= 454782
#
# step 101054
# [[5 2 7]
#  [1 0 3]
#  [6 4 8]]
# action= left , depth= 101054 , step cost= 1 , total_cost= 454783
#
# step 101055
# [[5 2 7]
#  [1 3 0]
#  [6 4 8]]
# action= left , depth= 101055 , step cost= 3 , total_cost= 454786
#
# step 101056
# [[5 2 0]
#  [1 3 7]
#  [6 4 8]]
# action= down , depth= 101056 , step cost= 7 , total_cost= 454793
#
# step 101057
# [[5 0 2]
#  [1 3 7]
#  [6 4 8]]
# action= right , depth= 101057 , step cost= 2 , total_cost= 454795
#
# step 101058
# [[0 5 2]
#  [1 3 7]
#  [6 4 8]]
# action= right , depth= 101058 , step cost= 5 , total_cost= 454800
#
# step 101059
# [[1 5 2]
#  [0 3 7]
#  [6 4 8]]
# action= up , depth= 101059 , step cost= 1 , total_cost= 454801
#
# step 101060
# [[1 5 2]
#  [3 0 7]
#  [6 4 8]]
# action= left , depth= 101060 , step cost= 3 , total_cost= 454804
#
# step 101061
# [[1 5 2]
#  [3 7 0]
#  [6 4 8]]
# action= left , depth= 101061 , step cost= 7 , total_cost= 454811
#
# step 101062
# [[1 5 2]
#  [3 7 8]
#  [6 4 0]]
# action= up , depth= 101062 , step cost= 8 , total_cost= 454819
#
# step 101063
# [[1 5 2]
#  [3 7 8]
#  [6 0 4]]
# action= right , depth= 101063 , step cost= 4 , total_cost= 454823
#
# step 101064
# [[1 5 2]
#  [3 7 8]
#  [0 6 4]]
# action= right , depth= 101064 , step cost= 6 , total_cost= 454829
#
# step 101065
# [[1 5 2]
#  [0 7 8]
#  [3 6 4]]
# action= down , depth= 101065 , step cost= 3 , total_cost= 454832
#
# step 101066
# [[1 5 2]
#  [7 0 8]
#  [3 6 4]]
# action= left , depth= 101066 , step cost= 7 , total_cost= 454839
#
# step 101067
# [[1 5 2]
#  [7 8 0]
#  [3 6 4]]
# action= left , depth= 101067 , step cost= 8 , total_cost= 454847
#
# step 101068
# [[1 5 0]
#  [7 8 2]
#  [3 6 4]]
# action= down , depth= 101068 , step cost= 2 , total_cost= 454849
#
# step 101069
# [[1 0 5]
#  [7 8 2]
#  [3 6 4]]
# action= right , depth= 101069 , step cost= 5 , total_cost= 454854
#
# step 101070
# [[0 1 5]
#  [7 8 2]
#  [3 6 4]]
# action= right , depth= 101070 , step cost= 1 , total_cost= 454855
#
# step 101071
# [[7 1 5]
#  [0 8 2]
#  [3 6 4]]
# action= up , depth= 101071 , step cost= 7 , total_cost= 454862
#
# step 101072
# [[7 1 5]
#  [8 0 2]
#  [3 6 4]]
# action= left , depth= 101072 , step cost= 8 , total_cost= 454870
#
# step 101073
# [[7 1 5]
#  [8 2 0]
#  [3 6 4]]
# action= left , depth= 101073 , step cost= 2 , total_cost= 454872
#
# step 101074
# [[7 1 0]
#  [8 2 5]
#  [3 6 4]]
# action= down , depth= 101074 , step cost= 5 , total_cost= 454877
#
# step 101075
# [[7 0 1]
#  [8 2 5]
#  [3 6 4]]
# action= right , depth= 101075 , step cost= 1 , total_cost= 454878
#
# step 101076
# [[0 7 1]
#  [8 2 5]
#  [3 6 4]]
# action= right , depth= 101076 , step cost= 7 , total_cost= 454885
#
# step 101077
# [[8 7 1]
#  [0 2 5]
#  [3 6 4]]
# action= up , depth= 101077 , step cost= 8 , total_cost= 454893
#
# step 101078
# [[8 7 1]
#  [2 0 5]
#  [3 6 4]]
# action= left , depth= 101078 , step cost= 2 , total_cost= 454895
#
# step 101079
# [[8 7 1]
#  [2 5 0]
#  [3 6 4]]
# action= left , depth= 101079 , step cost= 5 , total_cost= 454900
#
# step 101080
# [[8 7 0]
#  [2 5 1]
#  [3 6 4]]
# action= down , depth= 101080 , step cost= 1 , total_cost= 454901
#
# step 101081
# [[8 0 7]
#  [2 5 1]
#  [3 6 4]]
# action= right , depth= 101081 , step cost= 7 , total_cost= 454908
#
# step 101082
# [[0 8 7]
#  [2 5 1]
#  [3 6 4]]
# action= right , depth= 101082 , step cost= 8 , total_cost= 454916
#
# step 101083
# [[2 8 7]
#  [0 5 1]
#  [3 6 4]]
# action= up , depth= 101083 , step cost= 2 , total_cost= 454918
#
# step 101084
# [[2 8 7]
#  [5 0 1]
#  [3 6 4]]
# action= left , depth= 101084 , step cost= 5 , total_cost= 454923
#
# step 101085
# [[2 8 7]
#  [5 1 0]
#  [3 6 4]]
# action= left , depth= 101085 , step cost= 1 , total_cost= 454924
#
# step 101086
# [[2 8 0]
#  [5 1 7]
#  [3 6 4]]
# action= down , depth= 101086 , step cost= 7 , total_cost= 454931
#
# step 101087
# [[2 0 8]
#  [5 1 7]
#  [3 6 4]]
# action= right , depth= 101087 , step cost= 8 , total_cost= 454939
#
# step 101088
# [[0 2 8]
#  [5 1 7]
#  [3 6 4]]
# action= right , depth= 101088 , step cost= 2 , total_cost= 454941
#
# step 101089
# [[5 2 8]
#  [0 1 7]
#  [3 6 4]]
# action= up , depth= 101089 , step cost= 5 , total_cost= 454946
#
# step 101090
# [[5 2 8]
#  [3 1 7]
#  [0 6 4]]
# action= up , depth= 101090 , step cost= 3 , total_cost= 454949
#
# step 101091
# [[5 2 8]
#  [3 1 7]
#  [6 0 4]]
# action= left , depth= 101091 , step cost= 6 , total_cost= 454955
#
# step 101092
# [[5 2 8]
#  [3 0 7]
#  [6 1 4]]
# action= down , depth= 101092 , step cost= 1 , total_cost= 454956
#
# step 101093
# [[5 2 8]
#  [0 3 7]
#  [6 1 4]]
# action= right , depth= 101093 , step cost= 3 , total_cost= 454959
#
# step 101094
# [[0 2 8]
#  [5 3 7]
#  [6 1 4]]
# action= down , depth= 101094 , step cost= 5 , total_cost= 454964
#
# step 101095
# [[2 0 8]
#  [5 3 7]
#  [6 1 4]]
# action= left , depth= 101095 , step cost= 2 , total_cost= 454966
#
# step 101096
# [[2 8 0]
#  [5 3 7]
#  [6 1 4]]
# action= left , depth= 101096 , step cost= 8 , total_cost= 454974
#
# step 101097
# [[2 8 7]
#  [5 3 0]
#  [6 1 4]]
# action= up , depth= 101097 , step cost= 7 , total_cost= 454981
#
# step 101098
# [[2 8 7]
#  [5 0 3]
#  [6 1 4]]
# action= right , depth= 101098 , step cost= 3 , total_cost= 454984
#
# step 101099
# [[2 8 7]
#  [0 5 3]
#  [6 1 4]]
# action= right , depth= 101099 , step cost= 5 , total_cost= 454989
#
# step 101100
# [[0 8 7]
#  [2 5 3]
#  [6 1 4]]
# action= down , depth= 101100 , step cost= 2 , total_cost= 454991
#
# step 101101
# [[8 0 7]
#  [2 5 3]
#  [6 1 4]]
# action= left , depth= 101101 , step cost= 8 , total_cost= 454999
#
# step 101102
# [[8 7 0]
#  [2 5 3]
#  [6 1 4]]
# action= left , depth= 101102 , step cost= 7 , total_cost= 455006
#
# step 101103
# [[8 7 3]
#  [2 5 0]
#  [6 1 4]]
# action= up , depth= 101103 , step cost= 3 , total_cost= 455009
#
# step 101104
# [[8 7 3]
#  [2 0 5]
#  [6 1 4]]
# action= right , depth= 101104 , step cost= 5 , total_cost= 455014
#
# step 101105
# [[8 7 3]
#  [0 2 5]
#  [6 1 4]]
# action= right , depth= 101105 , step cost= 2 , total_cost= 455016
#
# step 101106
# [[0 7 3]
#  [8 2 5]
#  [6 1 4]]
# action= down , depth= 101106 , step cost= 8 , total_cost= 455024
#
# step 101107
# [[7 0 3]
#  [8 2 5]
#  [6 1 4]]
# action= left , depth= 101107 , step cost= 7 , total_cost= 455031
#
# step 101108
# [[7 3 0]
#  [8 2 5]
#  [6 1 4]]
# action= left , depth= 101108 , step cost= 3 , total_cost= 455034
#
# step 101109
# [[7 3 5]
#  [8 2 0]
#  [6 1 4]]
# action= up , depth= 101109 , step cost= 5 , total_cost= 455039
#
# step 101110
# [[7 3 5]
#  [8 0 2]
#  [6 1 4]]
# action= right , depth= 101110 , step cost= 2 , total_cost= 455041
#
# step 101111
# [[7 3 5]
#  [0 8 2]
#  [6 1 4]]
# action= right , depth= 101111 , step cost= 8 , total_cost= 455049
#
# step 101112
# [[0 3 5]
#  [7 8 2]
#  [6 1 4]]
# action= down , depth= 101112 , step cost= 7 , total_cost= 455056
#
# step 101113
# [[3 0 5]
#  [7 8 2]
#  [6 1 4]]
# action= left , depth= 101113 , step cost= 3 , total_cost= 455059
#
# step 101114
# [[3 5 0]
#  [7 8 2]
#  [6 1 4]]
# action= left , depth= 101114 , step cost= 5 , total_cost= 455064
#
# step 101115
# [[3 5 2]
#  [7 8 0]
#  [6 1 4]]
# action= up , depth= 101115 , step cost= 2 , total_cost= 455066
#
# step 101116
# [[3 5 2]
#  [7 0 8]
#  [6 1 4]]
# action= right , depth= 101116 , step cost= 8 , total_cost= 455074
#
# step 101117
# [[3 5 2]
#  [0 7 8]
#  [6 1 4]]
# action= right , depth= 101117 , step cost= 7 , total_cost= 455081
#
# step 101118
# [[0 5 2]
#  [3 7 8]
#  [6 1 4]]
# action= down , depth= 101118 , step cost= 3 , total_cost= 455084
#
# step 101119
# [[5 0 2]
#  [3 7 8]
#  [6 1 4]]
# action= left , depth= 101119 , step cost= 5 , total_cost= 455089
#
# step 101120
# [[5 2 0]
#  [3 7 8]
#  [6 1 4]]
# action= left , depth= 101120 , step cost= 2 , total_cost= 455091
#
# step 101121
# [[5 2 8]
#  [3 7 0]
#  [6 1 4]]
# action= up , depth= 101121 , step cost= 8 , total_cost= 455099
#
# step 101122
# [[5 2 8]
#  [3 7 4]
#  [6 1 0]]
# action= up , depth= 101122 , step cost= 4 , total_cost= 455103
#
# step 101123
# [[5 2 8]
#  [3 7 4]
#  [6 0 1]]
# action= right , depth= 101123 , step cost= 1 , total_cost= 455104
#
# step 101124
# [[5 2 8]
#  [3 7 4]
#  [0 6 1]]
# action= right , depth= 101124 , step cost= 6 , total_cost= 455110
#
# step 101125
# [[5 2 8]
#  [0 7 4]
#  [3 6 1]]
# action= down , depth= 101125 , step cost= 3 , total_cost= 455113
#
# step 101126
# [[5 2 8]
#  [7 0 4]
#  [3 6 1]]
# action= left , depth= 101126 , step cost= 7 , total_cost= 455120
#
# step 101127
# [[5 2 8]
#  [7 4 0]
#  [3 6 1]]
# action= left , depth= 101127 , step cost= 4 , total_cost= 455124
#
# step 101128
# [[5 2 0]
#  [7 4 8]
#  [3 6 1]]
# action= down , depth= 101128 , step cost= 8 , total_cost= 455132
#
# step 101129
# [[5 0 2]
#  [7 4 8]
#  [3 6 1]]
# action= right , depth= 101129 , step cost= 2 , total_cost= 455134
#
# step 101130
# [[0 5 2]
#  [7 4 8]
#  [3 6 1]]
# action= right , depth= 101130 , step cost= 5 , total_cost= 455139
#
# step 101131
# [[7 5 2]
#  [0 4 8]
#  [3 6 1]]
# action= up , depth= 101131 , step cost= 7 , total_cost= 455146
#
# step 101132
# [[7 5 2]
#  [4 0 8]
#  [3 6 1]]
# action= left , depth= 101132 , step cost= 4 , total_cost= 455150
#
# step 101133
# [[7 5 2]
#  [4 8 0]
#  [3 6 1]]
# action= left , depth= 101133 , step cost= 8 , total_cost= 455158
#
# step 101134
# [[7 5 0]
#  [4 8 2]
#  [3 6 1]]
# action= down , depth= 101134 , step cost= 2 , total_cost= 455160
#
# step 101135
# [[7 0 5]
#  [4 8 2]
#  [3 6 1]]
# action= right , depth= 101135 , step cost= 5 , total_cost= 455165
#
# step 101136
# [[0 7 5]
#  [4 8 2]
#  [3 6 1]]
# action= right , depth= 101136 , step cost= 7 , total_cost= 455172
#
# step 101137
# [[4 7 5]
#  [0 8 2]
#  [3 6 1]]
# action= up , depth= 101137 , step cost= 4 , total_cost= 455176
#
# step 101138
# [[4 7 5]
#  [8 0 2]
#  [3 6 1]]
# action= left , depth= 101138 , step cost= 8 , total_cost= 455184
#
# step 101139
# [[4 7 5]
#  [8 2 0]
#  [3 6 1]]
# action= left , depth= 101139 , step cost= 2 , total_cost= 455186
#
# step 101140
# [[4 7 5]
#  [8 2 1]
#  [3 6 0]]
# action= up , depth= 101140 , step cost= 1 , total_cost= 455187
#
# step 101141
# [[4 7 5]
#  [8 2 1]
#  [3 0 6]]
# action= right , depth= 101141 , step cost= 6 , total_cost= 455193
#
# step 101142
# [[4 7 5]
#  [8 2 1]
#  [0 3 6]]
# action= right , depth= 101142 , step cost= 3 , total_cost= 455196
#
# step 101143
# [[4 7 5]
#  [0 2 1]
#  [8 3 6]]
# action= down , depth= 101143 , step cost= 8 , total_cost= 455204
#
# step 101144
# [[4 7 5]
#  [2 0 1]
#  [8 3 6]]
# action= left , depth= 101144 , step cost= 2 , total_cost= 455206
#
# step 101145
# [[4 7 5]
#  [2 1 0]
#  [8 3 6]]
# action= left , depth= 101145 , step cost= 1 , total_cost= 455207
#
# step 101146
# [[4 7 0]
#  [2 1 5]
#  [8 3 6]]
# action= down , depth= 101146 , step cost= 5 , total_cost= 455212
#
# step 101147
# [[4 0 7]
#  [2 1 5]
#  [8 3 6]]
# action= right , depth= 101147 , step cost= 7 , total_cost= 455219
#
# step 101148
# [[0 4 7]
#  [2 1 5]
#  [8 3 6]]
# action= right , depth= 101148 , step cost= 4 , total_cost= 455223
#
# step 101149
# [[2 4 7]
#  [0 1 5]
#  [8 3 6]]
# action= up , depth= 101149 , step cost= 2 , total_cost= 455225
#
# step 101150
# [[2 4 7]
#  [1 0 5]
#  [8 3 6]]
# action= left , depth= 101150 , step cost= 1 , total_cost= 455226
#
# step 101151
# [[2 4 7]
#  [1 5 0]
#  [8 3 6]]
# action= left , depth= 101151 , step cost= 5 , total_cost= 455231
#
# step 101152
# [[2 4 0]
#  [1 5 7]
#  [8 3 6]]
# action= down , depth= 101152 , step cost= 7 , total_cost= 455238
#
# step 101153
# [[2 0 4]
#  [1 5 7]
#  [8 3 6]]
# action= right , depth= 101153 , step cost= 4 , total_cost= 455242
#
# step 101154
# [[0 2 4]
#  [1 5 7]
#  [8 3 6]]
# action= right , depth= 101154 , step cost= 2 , total_cost= 455244
#
# step 101155
# [[1 2 4]
#  [0 5 7]
#  [8 3 6]]
# action= up , depth= 101155 , step cost= 1 , total_cost= 455245
#
# step 101156
# [[1 2 4]
#  [5 0 7]
#  [8 3 6]]
# action= left , depth= 101156 , step cost= 5 , total_cost= 455250
#
# step 101157
# [[1 2 4]
#  [5 7 0]
#  [8 3 6]]
# action= left , depth= 101157 , step cost= 7 , total_cost= 455257
#
# step 101158
# [[1 2 0]
#  [5 7 4]
#  [8 3 6]]
# action= down , depth= 101158 , step cost= 4 , total_cost= 455261
#
# step 101159
# [[1 0 2]
#  [5 7 4]
#  [8 3 6]]
# action= right , depth= 101159 , step cost= 2 , total_cost= 455263
#
# step 101160
# [[0 1 2]
#  [5 7 4]
#  [8 3 6]]
# action= right , depth= 101160 , step cost= 1 , total_cost= 455264
#
# step 101161
# [[5 1 2]
#  [0 7 4]
#  [8 3 6]]
# action= up , depth= 101161 , step cost= 5 , total_cost= 455269
#
# step 101162
# [[5 1 2]
#  [7 0 4]
#  [8 3 6]]
# action= left , depth= 101162 , step cost= 7 , total_cost= 455276
#
# step 101163
# [[5 1 2]
#  [7 4 0]
#  [8 3 6]]
# action= left , depth= 101163 , step cost= 4 , total_cost= 455280
#
# step 101164
# [[5 1 0]
#  [7 4 2]
#  [8 3 6]]
# action= down , depth= 101164 , step cost= 2 , total_cost= 455282
#
# step 101165
# [[5 0 1]
#  [7 4 2]
#  [8 3 6]]
# action= right , depth= 101165 , step cost= 1 , total_cost= 455283
#
# step 101166
# [[0 5 1]
#  [7 4 2]
#  [8 3 6]]
# action= right , depth= 101166 , step cost= 5 , total_cost= 455288
#
# step 101167
# [[7 5 1]
#  [0 4 2]
#  [8 3 6]]
# action= up , depth= 101167 , step cost= 7 , total_cost= 455295
#
# step 101168
# [[7 5 1]
#  [4 0 2]
#  [8 3 6]]
# action= left , depth= 101168 , step cost= 4 , total_cost= 455299
#
# step 101169
# [[7 5 1]
#  [4 2 0]
#  [8 3 6]]
# action= left , depth= 101169 , step cost= 2 , total_cost= 455301
#
# step 101170
# [[7 5 1]
#  [4 2 6]
#  [8 3 0]]
# action= up , depth= 101170 , step cost= 6 , total_cost= 455307
#
# step 101171
# [[7 5 1]
#  [4 2 6]
#  [8 0 3]]
# action= right , depth= 101171 , step cost= 3 , total_cost= 455310
#
# step 101172
# [[7 5 1]
#  [4 2 6]
#  [0 8 3]]
# action= right , depth= 101172 , step cost= 8 , total_cost= 455318
#
# step 101173
# [[7 5 1]
#  [0 2 6]
#  [4 8 3]]
# action= down , depth= 101173 , step cost= 4 , total_cost= 455322
#
# step 101174
# [[7 5 1]
#  [2 0 6]
#  [4 8 3]]
# action= left , depth= 101174 , step cost= 2 , total_cost= 455324
#
# step 101175
# [[7 5 1]
#  [2 6 0]
#  [4 8 3]]
# action= left , depth= 101175 , step cost= 6 , total_cost= 455330
#
# step 101176
# [[7 5 0]
#  [2 6 1]
#  [4 8 3]]
# action= down , depth= 101176 , step cost= 1 , total_cost= 455331
#
# step 101177
# [[7 0 5]
#  [2 6 1]
#  [4 8 3]]
# action= right , depth= 101177 , step cost= 5 , total_cost= 455336
#
# step 101178
# [[0 7 5]
#  [2 6 1]
#  [4 8 3]]
# action= right , depth= 101178 , step cost= 7 , total_cost= 455343
#
# step 101179
# [[2 7 5]
#  [0 6 1]
#  [4 8 3]]
# action= up , depth= 101179 , step cost= 2 , total_cost= 455345
#
# step 101180
# [[2 7 5]
#  [6 0 1]
#  [4 8 3]]
# action= left , depth= 101180 , step cost= 6 , total_cost= 455351
#
# step 101181
# [[2 7 5]
#  [6 1 0]
#  [4 8 3]]
# action= left , depth= 101181 , step cost= 1 , total_cost= 455352
#
# step 101182
# [[2 7 0]
#  [6 1 5]
#  [4 8 3]]
# action= down , depth= 101182 , step cost= 5 , total_cost= 455357
#
# step 101183
# [[2 0 7]
#  [6 1 5]
#  [4 8 3]]
# action= right , depth= 101183 , step cost= 7 , total_cost= 455364
#
# step 101184
# [[0 2 7]
#  [6 1 5]
#  [4 8 3]]
# action= right , depth= 101184 , step cost= 2 , total_cost= 455366
#
# step 101185
# [[6 2 7]
#  [0 1 5]
#  [4 8 3]]
# action= up , depth= 101185 , step cost= 6 , total_cost= 455372
#
# step 101186
# [[6 2 7]
#  [1 0 5]
#  [4 8 3]]
# action= left , depth= 101186 , step cost= 1 , total_cost= 455373
#
# step 101187
# [[6 2 7]
#  [1 5 0]
#  [4 8 3]]
# action= left , depth= 101187 , step cost= 5 , total_cost= 455378
#
# step 101188
# [[6 2 0]
#  [1 5 7]
#  [4 8 3]]
# action= down , depth= 101188 , step cost= 7 , total_cost= 455385
#
# step 101189
# [[6 0 2]
#  [1 5 7]
#  [4 8 3]]
# action= right , depth= 101189 , step cost= 2 , total_cost= 455387
#
# step 101190
# [[0 6 2]
#  [1 5 7]
#  [4 8 3]]
# action= right , depth= 101190 , step cost= 6 , total_cost= 455393
#
# step 101191
# [[1 6 2]
#  [0 5 7]
#  [4 8 3]]
# action= up , depth= 101191 , step cost= 1 , total_cost= 455394
#
# step 101192
# [[1 6 2]
#  [5 0 7]
#  [4 8 3]]
# action= left , depth= 101192 , step cost= 5 , total_cost= 455399
#
# step 101193
# [[1 6 2]
#  [5 7 0]
#  [4 8 3]]
# action= left , depth= 101193 , step cost= 7 , total_cost= 455406
#
# step 101194
# [[1 6 0]
#  [5 7 2]
#  [4 8 3]]
# action= down , depth= 101194 , step cost= 2 , total_cost= 455408
#
# step 101195
# [[1 0 6]
#  [5 7 2]
#  [4 8 3]]
# action= right , depth= 101195 , step cost= 6 , total_cost= 455414
#
# step 101196
# [[0 1 6]
#  [5 7 2]
#  [4 8 3]]
# action= right , depth= 101196 , step cost= 1 , total_cost= 455415
#
# step 101197
# [[5 1 6]
#  [0 7 2]
#  [4 8 3]]
# action= up , depth= 101197 , step cost= 5 , total_cost= 455420
#
# step 101198
# [[5 1 6]
#  [7 0 2]
#  [4 8 3]]
# action= left , depth= 101198 , step cost= 7 , total_cost= 455427
#
# step 101199
# [[5 1 6]
#  [7 2 0]
#  [4 8 3]]
# action= left , depth= 101199 , step cost= 2 , total_cost= 455429
#
# step 101200
# [[5 1 0]
#  [7 2 6]
#  [4 8 3]]
# action= down , depth= 101200 , step cost= 6 , total_cost= 455435
#
# step 101201
# [[5 0 1]
#  [7 2 6]
#  [4 8 3]]
# action= right , depth= 101201 , step cost= 1 , total_cost= 455436
#
# step 101202
# [[5 2 1]
#  [7 0 6]
#  [4 8 3]]
# action= up , depth= 101202 , step cost= 2 , total_cost= 455438
#
# step 101203
# [[5 2 1]
#  [0 7 6]
#  [4 8 3]]
# action= right , depth= 101203 , step cost= 7 , total_cost= 455445
#
# step 101204
# [[0 2 1]
#  [5 7 6]
#  [4 8 3]]
# action= down , depth= 101204 , step cost= 5 , total_cost= 455450
#
# step 101205
# [[2 0 1]
#  [5 7 6]
#  [4 8 3]]
# action= left , depth= 101205 , step cost= 2 , total_cost= 455452
#
# step 101206
# [[2 1 0]
#  [5 7 6]
#  [4 8 3]]
# action= left , depth= 101206 , step cost= 1 , total_cost= 455453
#
# step 101207
# [[2 1 6]
#  [5 7 0]
#  [4 8 3]]
# action= up , depth= 101207 , step cost= 6 , total_cost= 455459
#
# step 101208
# [[2 1 6]
#  [5 0 7]
#  [4 8 3]]
# action= right , depth= 101208 , step cost= 7 , total_cost= 455466
#
# step 101209
# [[2 1 6]
#  [0 5 7]
#  [4 8 3]]
# action= right , depth= 101209 , step cost= 5 , total_cost= 455471
#
# step 101210
# [[0 1 6]
#  [2 5 7]
#  [4 8 3]]
# action= down , depth= 101210 , step cost= 2 , total_cost= 455473
#
# step 101211
# [[1 0 6]
#  [2 5 7]
#  [4 8 3]]
# action= left , depth= 101211 , step cost= 1 , total_cost= 455474
#
# step 101212
# [[1 6 0]
#  [2 5 7]
#  [4 8 3]]
# action= left , depth= 101212 , step cost= 6 , total_cost= 455480
#
# step 101213
# [[1 6 7]
#  [2 5 0]
#  [4 8 3]]
# action= up , depth= 101213 , step cost= 7 , total_cost= 455487
#
# step 101214
# [[1 6 7]
#  [2 0 5]
#  [4 8 3]]
# action= right , depth= 101214 , step cost= 5 , total_cost= 455492
#
# step 101215
# [[1 6 7]
#  [0 2 5]
#  [4 8 3]]
# action= right , depth= 101215 , step cost= 2 , total_cost= 455494
#
# step 101216
# [[0 6 7]
#  [1 2 5]
#  [4 8 3]]
# action= down , depth= 101216 , step cost= 1 , total_cost= 455495
#
# step 101217
# [[6 0 7]
#  [1 2 5]
#  [4 8 3]]
# action= left , depth= 101217 , step cost= 6 , total_cost= 455501
#
# step 101218
# [[6 7 0]
#  [1 2 5]
#  [4 8 3]]
# action= left , depth= 101218 , step cost= 7 , total_cost= 455508
#
# step 101219
# [[6 7 5]
#  [1 2 0]
#  [4 8 3]]
# action= up , depth= 101219 , step cost= 5 , total_cost= 455513
#
# step 101220
# [[6 7 5]
#  [1 0 2]
#  [4 8 3]]
# action= right , depth= 101220 , step cost= 2 , total_cost= 455515
#
# step 101221
# [[6 7 5]
#  [0 1 2]
#  [4 8 3]]
# action= right , depth= 101221 , step cost= 1 , total_cost= 455516
#
# step 101222
# [[0 7 5]
#  [6 1 2]
#  [4 8 3]]
# action= down , depth= 101222 , step cost= 6 , total_cost= 455522
#
# step 101223
# [[7 0 5]
#  [6 1 2]
#  [4 8 3]]
# action= left , depth= 101223 , step cost= 7 , total_cost= 455529
#
# step 101224
# [[7 5 0]
#  [6 1 2]
#  [4 8 3]]
# action= left , depth= 101224 , step cost= 5 , total_cost= 455534
#
# step 101225
# [[7 5 2]
#  [6 1 0]
#  [4 8 3]]
# action= up , depth= 101225 , step cost= 2 , total_cost= 455536
#
# step 101226
# [[7 5 2]
#  [6 0 1]
#  [4 8 3]]
# action= right , depth= 101226 , step cost= 1 , total_cost= 455537
#
# step 101227
# [[7 5 2]
#  [0 6 1]
#  [4 8 3]]
# action= right , depth= 101227 , step cost= 6 , total_cost= 455543
#
# step 101228
# [[0 5 2]
#  [7 6 1]
#  [4 8 3]]
# action= down , depth= 101228 , step cost= 7 , total_cost= 455550
#
# step 101229
# [[5 0 2]
#  [7 6 1]
#  [4 8 3]]
# action= left , depth= 101229 , step cost= 5 , total_cost= 455555
#
# step 101230
# [[5 2 0]
#  [7 6 1]
#  [4 8 3]]
# action= left , depth= 101230 , step cost= 2 , total_cost= 455557
#
# step 101231
# [[5 2 1]
#  [7 6 0]
#  [4 8 3]]
# action= up , depth= 101231 , step cost= 1 , total_cost= 455558
#
# step 101232
# [[5 2 1]
#  [7 6 3]
#  [4 8 0]]
# action= up , depth= 101232 , step cost= 3 , total_cost= 455561
#
# step 101233
# [[5 2 1]
#  [7 6 3]
#  [4 0 8]]
# action= right , depth= 101233 , step cost= 8 , total_cost= 455569
#
# step 101234
# [[5 2 1]
#  [7 6 3]
#  [0 4 8]]
# action= right , depth= 101234 , step cost= 4 , total_cost= 455573
#
# step 101235
# [[5 2 1]
#  [0 6 3]
#  [7 4 8]]
# action= down , depth= 101235 , step cost= 7 , total_cost= 455580
#
# step 101236
# [[5 2 1]
#  [6 0 3]
#  [7 4 8]]
# action= left , depth= 101236 , step cost= 6 , total_cost= 455586
#
# step 101237
# [[5 2 1]
#  [6 3 0]
#  [7 4 8]]
# action= left , depth= 101237 , step cost= 3 , total_cost= 455589
#
# step 101238
# [[5 2 0]
#  [6 3 1]
#  [7 4 8]]
# action= down , depth= 101238 , step cost= 1 , total_cost= 455590
#
# step 101239
# [[5 0 2]
#  [6 3 1]
#  [7 4 8]]
# action= right , depth= 101239 , step cost= 2 , total_cost= 455592
#
# step 101240
# [[0 5 2]
#  [6 3 1]
#  [7 4 8]]
# action= right , depth= 101240 , step cost= 5 , total_cost= 455597
#
# step 101241
# [[6 5 2]
#  [0 3 1]
#  [7 4 8]]
# action= up , depth= 101241 , step cost= 6 , total_cost= 455603
#
# step 101242
# [[6 5 2]
#  [3 0 1]
#  [7 4 8]]
# action= left , depth= 101242 , step cost= 3 , total_cost= 455606
#
# step 101243
# [[6 5 2]
#  [3 1 0]
#  [7 4 8]]
# action= left , depth= 101243 , step cost= 1 , total_cost= 455607
#
# step 101244
# [[6 5 0]
#  [3 1 2]
#  [7 4 8]]
# action= down , depth= 101244 , step cost= 2 , total_cost= 455609
#
# step 101245
# [[6 0 5]
#  [3 1 2]
#  [7 4 8]]
# action= right , depth= 101245 , step cost= 5 , total_cost= 455614
#
# step 101246
# [[0 6 5]
#  [3 1 2]
#  [7 4 8]]
# action= right , depth= 101246 , step cost= 6 , total_cost= 455620
#
# step 101247
# [[3 6 5]
#  [0 1 2]
#  [7 4 8]]
# action= up , depth= 101247 , step cost= 3 , total_cost= 455623
#
# step 101248
# [[3 6 5]
#  [1 0 2]
#  [7 4 8]]
# action= left , depth= 101248 , step cost= 1 , total_cost= 455624
#
# step 101249
# [[3 6 5]
#  [1 2 0]
#  [7 4 8]]
# action= left , depth= 101249 , step cost= 2 , total_cost= 455626
#
# step 101250
# [[3 6 0]
#  [1 2 5]
#  [7 4 8]]
# action= down , depth= 101250 , step cost= 5 , total_cost= 455631
#
# step 101251
# [[3 0 6]
#  [1 2 5]
#  [7 4 8]]
# action= right , depth= 101251 , step cost= 6 , total_cost= 455637
#
# step 101252
# [[0 3 6]
#  [1 2 5]
#  [7 4 8]]
# action= right , depth= 101252 , step cost= 3 , total_cost= 455640
#
# step 101253
# [[1 3 6]
#  [0 2 5]
#  [7 4 8]]
# action= up , depth= 101253 , step cost= 1 , total_cost= 455641
#
# step 101254
# [[1 3 6]
#  [2 0 5]
#  [7 4 8]]
# action= left , depth= 101254 , step cost= 2 , total_cost= 455643
#
# step 101255
# [[1 3 6]
#  [2 5 0]
#  [7 4 8]]
# action= left , depth= 101255 , step cost= 5 , total_cost= 455648
#
# step 101256
# [[1 3 0]
#  [2 5 6]
#  [7 4 8]]
# action= down , depth= 101256 , step cost= 6 , total_cost= 455654
#
# step 101257
# [[1 0 3]
#  [2 5 6]
#  [7 4 8]]
# action= right , depth= 101257 , step cost= 3 , total_cost= 455657
#
# step 101258
# [[0 1 3]
#  [2 5 6]
#  [7 4 8]]
# action= right , depth= 101258 , step cost= 1 , total_cost= 455658
#
# step 101259
# [[2 1 3]
#  [0 5 6]
#  [7 4 8]]
# action= up , depth= 101259 , step cost= 2 , total_cost= 455660
#
# step 101260
# [[2 1 3]
#  [5 0 6]
#  [7 4 8]]
# action= left , depth= 101260 , step cost= 5 , total_cost= 455665
#
# step 101261
# [[2 1 3]
#  [5 4 6]
#  [7 0 8]]
# action= up , depth= 101261 , step cost= 4 , total_cost= 455669
#
# step 101262
# [[2 1 3]
#  [5 4 6]
#  [7 8 0]]
# action= left , depth= 101262 , step cost= 8 , total_cost= 455677
#
# step 101263
# [[2 1 3]
#  [5 4 0]
#  [7 8 6]]
# action= down , depth= 101263 , step cost= 6 , total_cost= 455683
#
# step 101264
# [[2 1 3]
#  [5 0 4]
#  [7 8 6]]
# action= right , depth= 101264 , step cost= 4 , total_cost= 455687
#
# step 101265
# [[2 1 3]
#  [0 5 4]
#  [7 8 6]]
# action= right , depth= 101265 , step cost= 5 , total_cost= 455692
#
# step 101266
# [[0 1 3]
#  [2 5 4]
#  [7 8 6]]
# action= down , depth= 101266 , step cost= 2 , total_cost= 455694
#
# step 101267
# [[1 0 3]
#  [2 5 4]
#  [7 8 6]]
# action= left , depth= 101267 , step cost= 1 , total_cost= 455695
#
# step 101268
# [[1 3 0]
#  [2 5 4]
#  [7 8 6]]
# action= left , depth= 101268 , step cost= 3 , total_cost= 455698
#
# step 101269
# [[1 3 4]
#  [2 5 0]
#  [7 8 6]]
# action= up , depth= 101269 , step cost= 4 , total_cost= 455702
#
# step 101270
# [[1 3 4]
#  [2 0 5]
#  [7 8 6]]
# action= right , depth= 101270 , step cost= 5 , total_cost= 455707
#
# step 101271
# [[1 3 4]
#  [0 2 5]
#  [7 8 6]]
# action= right , depth= 101271 , step cost= 2 , total_cost= 455709
#
# step 101272
# [[0 3 4]
#  [1 2 5]
#  [7 8 6]]
# action= down , depth= 101272 , step cost= 1 , total_cost= 455710
#
# step 101273
# [[3 0 4]
#  [1 2 5]
#  [7 8 6]]
# action= left , depth= 101273 , step cost= 3 , total_cost= 455713
#
# step 101274
# [[3 4 0]
#  [1 2 5]
#  [7 8 6]]
# action= left , depth= 101274 , step cost= 4 , total_cost= 455717
#
# step 101275
# [[3 4 5]
#  [1 2 0]
#  [7 8 6]]
# action= up , depth= 101275 , step cost= 5 , total_cost= 455722
#
# step 101276
# [[3 4 5]
#  [1 0 2]
#  [7 8 6]]
# action= right , depth= 101276 , step cost= 2 , total_cost= 455724
#
# step 101277
# [[3 4 5]
#  [0 1 2]
#  [7 8 6]]
# action= right , depth= 101277 , step cost= 1 , total_cost= 455725
#
# step 101278
# [[0 4 5]
#  [3 1 2]
#  [7 8 6]]
# action= down , depth= 101278 , step cost= 3 , total_cost= 455728
#
# step 101279
# [[4 0 5]
#  [3 1 2]
#  [7 8 6]]
# action= left , depth= 101279 , step cost= 4 , total_cost= 455732
#
# step 101280
# [[4 5 0]
#  [3 1 2]
#  [7 8 6]]
# action= left , depth= 101280 , step cost= 5 , total_cost= 455737
#
# step 101281
# [[4 5 2]
#  [3 1 0]
#  [7 8 6]]
# action= up , depth= 101281 , step cost= 2 , total_cost= 455739
#
# step 101282
# [[4 5 2]
#  [3 0 1]
#  [7 8 6]]
# action= right , depth= 101282 , step cost= 1 , total_cost= 455740
#
# step 101283
# [[4 5 2]
#  [0 3 1]
#  [7 8 6]]
# action= right , depth= 101283 , step cost= 3 , total_cost= 455743
#
# step 101284
# [[0 5 2]
#  [4 3 1]
#  [7 8 6]]
# action= down , depth= 101284 , step cost= 4 , total_cost= 455747
#
# step 101285
# [[5 0 2]
#  [4 3 1]
#  [7 8 6]]
# action= left , depth= 101285 , step cost= 5 , total_cost= 455752
#
# step 101286
# [[5 2 0]
#  [4 3 1]
#  [7 8 6]]
# action= left , depth= 101286 , step cost= 2 , total_cost= 455754
#
# step 101287
# [[5 2 1]
#  [4 3 0]
#  [7 8 6]]
# action= up , depth= 101287 , step cost= 1 , total_cost= 455755
#
# step 101288
# [[5 2 1]
#  [4 0 3]
#  [7 8 6]]
# action= right , depth= 101288 , step cost= 3 , total_cost= 455758
#
# step 101289
# [[5 2 1]
#  [4 8 3]
#  [7 0 6]]
# action= up , depth= 101289 , step cost= 8 , total_cost= 455766
#
# step 101290
# [[5 2 1]
#  [4 8 3]
#  [0 7 6]]
# action= right , depth= 101290 , step cost= 7 , total_cost= 455773
#
# step 101291
# [[5 2 1]
#  [0 8 3]
#  [4 7 6]]
# action= down , depth= 101291 , step cost= 4 , total_cost= 455777
#
# step 101292
# [[5 2 1]
#  [8 0 3]
#  [4 7 6]]
# action= left , depth= 101292 , step cost= 8 , total_cost= 455785
#
# step 101293
# [[5 2 1]
#  [8 3 0]
#  [4 7 6]]
# action= left , depth= 101293 , step cost= 3 , total_cost= 455788
#
# step 101294
# [[5 2 0]
#  [8 3 1]
#  [4 7 6]]
# action= down , depth= 101294 , step cost= 1 , total_cost= 455789
#
# step 101295
# [[5 0 2]
#  [8 3 1]
#  [4 7 6]]
# action= right , depth= 101295 , step cost= 2 , total_cost= 455791
#
# step 101296
# [[0 5 2]
# ...
#
# step 101532
# [[8 2 0]
#  [1 4 3]
#  [7 6 5]]
# action= left , depth= 101532 , step cost= 2 , total_cost= 456729
#
# step 101533
# [[8 2 3]
#  [1 4 0]
#  [7 6 5]]
# action= up , depth= 101533 , step cost= 3 , total_cost= 456732
#
# step 101534
# [[8 2 3]
#  [1 0 4]
#  [7 6 5]]
# action= right , depth= 101534 , step cost= 4 , total_cost= 456736
#
# step 101535
# [[8 2 3]
#  [0 1 4]
#  [7 6 5]]
# action= right , depth= 101535 , step cost= 1 , total_cost= 456737
#
# step 101536
# [[0 2 3]
#  [8 1 4]
#  [7 6 5]]
# action= down , depth= 101536 , step cost= 8 , total_cost= 456745
#
# step 101537
# [[2 0 3]
#  [8 1 4]
#  [7 6 5]]
# action= left , depth= 101537 , step cost= 2 , total_cost= 456747
#
# step 101538
# [[2 3 0]
#  [8 1 4]
#  [7 6 5]]
# action= left , depth= 101538 , step cost= 3 , total_cost= 456750
#
# step 101539
# [[2 3 4]
#  [8 1 0]
#  [7 6 5]]
# action= up , depth= 101539 , step cost= 4 , total_cost= 456754
#
# step 101540
# [[2 3 4]
#  [8 0 1]
#  [7 6 5]]
# action= right , depth= 101540 , step cost= 1 , total_cost= 456755
#
# step 101541
# [[2 3 4]
#  [0 8 1]
#  [7 6 5]]
# action= right , depth= 101541 , step cost= 8 , total_cost= 456763
#
# step 101542
# [[0 3 4]
#  [2 8 1]
#  [7 6 5]]
# action= down , depth= 101542 , step cost= 2 , total_cost= 456765
#
# step 101543
# [[3 0 4]
#  [2 8 1]
#  [7 6 5]]
# action= left , depth= 101543 , step cost= 3 , total_cost= 456768
#
# step 101544
# [[3 4 0]
#  [2 8 1]
#  [7 6 5]]
# action= left , depth= 101544 , step cost= 4 , total_cost= 456772
#
# step 101545
# [[3 4 1]
#  [2 8 0]
#  [7 6 5]]
# action= up , depth= 101545 , step cost= 1 , total_cost= 456773
#
# step 101546
# [[3 4 1]
#  [2 8 5]
#  [7 6 0]]
# action= up , depth= 101546 , step cost= 5 , total_cost= 456778
#
# step 101547
# [[3 4 1]
#  [2 8 5]
#  [7 0 6]]
# action= right , depth= 101547 , step cost= 6 , total_cost= 456784
#
# step 101548
# [[3 4 1]
#  [2 0 5]
#  [7 8 6]]
# action= down , depth= 101548 , step cost= 8 , total_cost= 456792
#
# step 101549
# [[3 4 1]
#  [0 2 5]
#  [7 8 6]]
# action= right , depth= 101549 , step cost= 2 , total_cost= 456794
#
# step 101550
# [[0 4 1]
#  [3 2 5]
#  [7 8 6]]
# action= down , depth= 101550 , step cost= 3 , total_cost= 456797
#
# step 101551
# [[4 0 1]
#  [3 2 5]
#  [7 8 6]]
# action= left , depth= 101551 , step cost= 4 , total_cost= 456801
#
# step 101552
# [[4 1 0]
#  [3 2 5]
#  [7 8 6]]
# action= left , depth= 101552 , step cost= 1 , total_cost= 456802
#
# step 101553
# [[4 1 5]
#  [3 2 0]
#  [7 8 6]]
# action= up , depth= 101553 , step cost= 5 , total_cost= 456807
#
# step 101554
# [[4 1 5]
#  [3 0 2]
#  [7 8 6]]
# action= right , depth= 101554 , step cost= 2 , total_cost= 456809
#
# step 101555
# [[4 1 5]
#  [0 3 2]
#  [7 8 6]]
# action= right , depth= 101555 , step cost= 3 , total_cost= 456812
#
# step 101556
# [[0 1 5]
#  [4 3 2]
#  [7 8 6]]
# action= down , depth= 101556 , step cost= 4 , total_cost= 456816
#
# step 101557
# [[1 0 5]
#  [4 3 2]
#  [7 8 6]]
# action= left , depth= 101557 , step cost= 1 , total_cost= 456817
#
# step 101558
# [[1 5 0]
#  [4 3 2]
#  [7 8 6]]
# action= left , depth= 101558 , step cost= 5 , total_cost= 456822
#
# step 101559
# [[1 5 2]
#  [4 3 0]
#  [7 8 6]]
# action= up , depth= 101559 , step cost= 2 , total_cost= 456824
#
# step 101560
# [[1 5 2]
#  [4 0 3]
#  [7 8 6]]
# action= right , depth= 101560 , step cost= 3 , total_cost= 456827
#
# step 101561
# [[1 5 2]
#  [0 4 3]
#  [7 8 6]]
# action= right , depth= 101561 , step cost= 4 , total_cost= 456831
#
# step 101562
# [[0 5 2]
#  [1 4 3]
#  [7 8 6]]
# action= down , depth= 101562 , step cost= 1 , total_cost= 456832
#
# step 101563
# [[5 0 2]
#  [1 4 3]
#  [7 8 6]]
# action= left , depth= 101563 , step cost= 5 , total_cost= 456837
#
# step 101564
# [[5 2 0]
#  [1 4 3]
#  [7 8 6]]
# action= left , depth= 101564 , step cost= 2 , total_cost= 456839
#
# step 101565
# [[5 2 3]
#  [1 4 0]
#  [7 8 6]]
# action= up , depth= 101565 , step cost= 3 , total_cost= 456842
#
# step 101566
# [[5 2 3]
#  [1 0 4]
#  [7 8 6]]
# action= right , depth= 101566 , step cost= 4 , total_cost= 456846
#
# step 101567
# [[5 2 3]
#  [0 1 4]
#  [7 8 6]]
# action= right , depth= 101567 , step cost= 1 , total_cost= 456847
#
# step 101568
# [[0 2 3]
#  [5 1 4]
#  [7 8 6]]
# action= down , depth= 101568 , step cost= 5 , total_cost= 456852
#
# step 101569
# [[2 0 3]
#  [5 1 4]
#  [7 8 6]]
# action= left , depth= 101569 , step cost= 2 , total_cost= 456854
#
# step 101570
# [[2 3 0]
#  [5 1 4]
#  [7 8 6]]
# action= left , depth= 101570 , step cost= 3 , total_cost= 456857
#
# step 101571
# [[2 3 4]
#  [5 1 0]
#  [7 8 6]]
# action= up , depth= 101571 , step cost= 4 , total_cost= 456861
#
# step 101572
# [[2 3 4]
#  [5 0 1]
#  [7 8 6]]
# action= right , depth= 101572 , step cost= 1 , total_cost= 456862
#
# step 101573
# [[2 3 4]
#  [0 5 1]
#  [7 8 6]]
# action= right , depth= 101573 , step cost= 5 , total_cost= 456867
#
# step 101574
# [[0 3 4]
#  [2 5 1]
#  [7 8 6]]
# action= down , depth= 101574 , step cost= 2 , total_cost= 456869
#
# step 101575
# [[3 0 4]
#  [2 5 1]
#  [7 8 6]]
# action= left , depth= 101575 , step cost= 3 , total_cost= 456872
#
# step 101576
# [[3 4 0]
#  [2 5 1]
#  [7 8 6]]
# action= left , depth= 101576 , step cost= 4 , total_cost= 456876
#
# step 101577
# [[3 4 1]
#  [2 5 0]
#  [7 8 6]]
# action= up , depth= 101577 , step cost= 1 , total_cost= 456877
#
# step 101578
# [[3 4 1]
#  [2 5 6]
#  [7 8 0]]
# action= up , depth= 101578 , step cost= 6 , total_cost= 456883
#
# step 101579
# [[3 4 1]
#  [2 5 6]
#  [7 0 8]]
# action= right , depth= 101579 , step cost= 8 , total_cost= 456891
#
# step 101580
# [[3 4 1]
#  [2 0 6]
#  [7 5 8]]
# action= down , depth= 101580 , step cost= 5 , total_cost= 456896
#
# step 101581
# [[3 4 1]
#  [0 2 6]
#  [7 5 8]]
# action= right , depth= 101581 , step cost= 2 , total_cost= 456898
#
# step 101582
# [[0 4 1]
#  [3 2 6]
#  [7 5 8]]
# action= down , depth= 101582 , step cost= 3 , total_cost= 456901
#
# step 101583
# [[4 0 1]
#  [3 2 6]
#  [7 5 8]]
# action= left , depth= 101583 , step cost= 4 , total_cost= 456905
#
# step 101584
# [[4 1 0]
#  [3 2 6]
#  [7 5 8]]
# action= left , depth= 101584 , step cost= 1 , total_cost= 456906
#
# step 101585
# [[4 1 6]
#  [3 2 0]
#  [7 5 8]]
# action= up , depth= 101585 , step cost= 6 , total_cost= 456912
#
# step 101586
# [[4 1 6]
#  [3 0 2]
#  [7 5 8]]
# action= right , depth= 101586 , step cost= 2 , total_cost= 456914
#
# step 101587
# [[4 1 6]
#  [0 3 2]
#  [7 5 8]]
# action= right , depth= 101587 , step cost= 3 , total_cost= 456917
#
# step 101588
# [[0 1 6]
#  [4 3 2]
#  [7 5 8]]
# action= down , depth= 101588 , step cost= 4 , total_cost= 456921
#
# step 101589
# [[1 0 6]
#  [4 3 2]
#  [7 5 8]]
# action= left , depth= 101589 , step cost= 1 , total_cost= 456922
#
# step 101590
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
# action= left , depth= 101590 , step cost= 6 , total_cost= 456928
#
# step 101591
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
# action= up , depth= 101591 , step cost= 2 , total_cost= 456930
#
# step 101592
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
# action= right , depth= 101592 , step cost= 3 , total_cost= 456933
#
# step 101593
# [[1 6 2]
#  [0 4 3]
#  [7 5 8]]
# action= right , depth= 101593 , step cost= 4 , total_cost= 456937
#
# step 101594
# [[0 6 2]
#  [1 4 3]
#  [7 5 8]]
# action= down , depth= 101594 , step cost= 1 , total_cost= 456938
#
# step 101595
# [[6 0 2]
#  [1 4 3]
#  [7 5 8]]
# action= left , depth= 101595 , step cost= 6 , total_cost= 456944
#
# step 101596
# [[6 2 0]
#  [1 4 3]
#  [7 5 8]]
# action= left , depth= 101596 , step cost= 2 , total_cost= 456946
#
# step 101597
# [[6 2 3]
#  [1 4 0]
#  [7 5 8]]
# action= up , depth= 101597 , step cost= 3 , total_cost= 456949
#
# step 101598
# [[6 2 3]
#  [1 0 4]
#  [7 5 8]]
# action= right , depth= 101598 , step cost= 4 , total_cost= 456953
#
# step 101599
# [[6 2 3]
#  [0 1 4]
#  [7 5 8]]
# action= right , depth= 101599 , step cost= 1 , total_cost= 456954
#
# step 101600
# [[0 2 3]
#  [6 1 4]
#  [7 5 8]]
# action= down , depth= 101600 , step cost= 6 , total_cost= 456960
#
# step 101601
# [[2 0 3]
#  [6 1 4]
#  [7 5 8]]
# action= left , depth= 101601 , step cost= 2 , total_cost= 456962
#
# step 101602
# [[2 3 0]
#  [6 1 4]
#  [7 5 8]]
# action= left , depth= 101602 , step cost= 3 , total_cost= 456965
#
# step 101603
# [[2 3 4]
#  [6 1 0]
#  [7 5 8]]
# action= up , depth= 101603 , step cost= 4 , total_cost= 456969
#
# step 101604
# [[2 3 4]
#  [6 0 1]
#  [7 5 8]]
# action= right , depth= 101604 , step cost= 1 , total_cost= 456970
#
# step 101605
# [[2 3 4]
#  [0 6 1]
#  [7 5 8]]
# action= right , depth= 101605 , step cost= 6 , total_cost= 456976
#
# step 101606
# [[0 3 4]
#  [2 6 1]
#  [7 5 8]]
# action= down , depth= 101606 , step cost= 2 , total_cost= 456978
#
# step 101607
# [[3 0 4]
#  [2 6 1]
#  [7 5 8]]
# action= left , depth= 101607 , step cost= 3 , total_cost= 456981
#
# step 101608
# [[3 6 4]
#  [2 0 1]
#  [7 5 8]]
# action= up , depth= 101608 , step cost= 6 , total_cost= 456987
#
# step 101609
# [[3 6 4]
#  [0 2 1]
#  [7 5 8]]
# action= right , depth= 101609 , step cost= 2 , total_cost= 456989
#
# step 101610
# [[0 6 4]
#  [3 2 1]
#  [7 5 8]]
# action= down , depth= 101610 , step cost= 3 , total_cost= 456992
#
# step 101611
# [[6 0 4]
#  [3 2 1]
#  [7 5 8]]
# action= left , depth= 101611 , step cost= 6 , total_cost= 456998
#
# step 101612
# [[6 4 0]
#  [3 2 1]
#  [7 5 8]]
# action= left , depth= 101612 , step cost= 4 , total_cost= 457002
#
# step 101613
# [[6 4 1]
#  [3 2 0]
#  [7 5 8]]
# action= up , depth= 101613 , step cost= 1 , total_cost= 457003
#
# step 101614
# [[6 4 1]
#  [3 0 2]
#  [7 5 8]]
# action= right , depth= 101614 , step cost= 2 , total_cost= 457005
#
# step 101615
# [[6 4 1]
#  [0 3 2]
#  [7 5 8]]
# action= right , depth= 101615 , step cost= 3 , total_cost= 457008
#
# step 101616
# [[0 4 1]
#  [6 3 2]
#  [7 5 8]]
# action= down , depth= 101616 , step cost= 6 , total_cost= 457014
#
# step 101617
# [[4 0 1]
#  [6 3 2]
#  [7 5 8]]
# action= left , depth= 101617 , step cost= 4 , total_cost= 457018
#
# step 101618
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
# action= left , depth= 101618 , step cost= 1 , total_cost= 457019
#
# step 101619
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
# action= up , depth= 101619 , step cost= 2 , total_cost= 457021
#
# step 101620
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
# action= right , depth= 101620 , step cost= 3 , total_cost= 457024
#
# step 101621
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
# action= right , depth= 101621 , step cost= 6 , total_cost= 457030
#
# step 101622
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
# action= down , depth= 101622 , step cost= 4 , total_cost= 457034
#
# step 101623
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
# action= left , depth= 101623 , step cost= 1 , total_cost= 457035
#
# step 101624
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
# action= left , depth= 101624 , step cost= 2 , total_cost= 457037
#
# step 101625
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
# action= up , depth= 101625 , step cost= 3 , total_cost= 457040
#
# step 101626
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# action= right , depth= 101626 , step cost= 6 , total_cost= 457046
#
# step 101627
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
# action= right , depth= 101627 , step cost= 4 , total_cost= 457050
#
# step 101628
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
# action= down , depth= 101628 , step cost= 1 , total_cost= 457051
#
# step 101629
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
# action= left , depth= 101629 , step cost= 2 , total_cost= 457053
#
# step 101630
# [[2 3 0]
#  [1 4 6]
#  [7 5 8]]
# action= left , depth= 101630 , step cost= 3 , total_cost= 457056
#
# step 101631
# [[2 3 6]
#  [1 4 0]
#  [7 5 8]]
# action= up , depth= 101631 , step cost= 6 , total_cost= 457062
#
# step 101632
# [[2 3 6]
#  [1 0 4]
#  [7 5 8]]
# action= right , depth= 101632 , step cost= 4 , total_cost= 457066
#
# step 101633
# [[2 3 6]
#  [1 5 4]
#  [7 0 8]]
# action= up , depth= 101633 , step cost= 5 , total_cost= 457071
#
# step 101634
# [[2 3 6]
#  [1 5 4]
#  [7 8 0]]
# action= left , depth= 101634 , step cost= 8 , total_cost= 457079
#
# step 101635
# [[2 3 6]
#  [1 5 0]
#  [7 8 4]]
# action= down , depth= 101635 , step cost= 4 , total_cost= 457083
#
# step 101636
# [[2 3 6]
#  [1 0 5]
#  [7 8 4]]
# action= right , depth= 101636 , step cost= 5 , total_cost= 457088
#
# step 101637
# [[2 3 6]
#  [0 1 5]
#  [7 8 4]]
# action= right , depth= 101637 , step cost= 1 , total_cost= 457089
#
# step 101638
# [[0 3 6]
#  [2 1 5]
#  [7 8 4]]
# action= down , depth= 101638 , step cost= 2 , total_cost= 457091
#
# step 101639
# [[3 0 6]
#  [2 1 5]
#  [7 8 4]]
# action= left , depth= 101639 , step cost= 3 , total_cost= 457094
#
# step 101640
# [[3 6 0]
#  [2 1 5]
#  [7 8 4]]
# action= left , depth= 101640 , step cost= 6 , total_cost= 457100
#
# step 101641
# [[3 6 5]
#  [2 1 0]
#  [7 8 4]]
# action= up , depth= 101641 , step cost= 5 , total_cost= 457105
#
# step 101642
# [[3 6 5]
#  [2 1 4]
#  [7 8 0]]
# action= up , depth= 101642 , step cost= 4 , total_cost= 457109
#
# step 101643
# [[3 6 5]
#  [2 1 4]
#  [7 0 8]]
# action= right , depth= 101643 , step cost= 8 , total_cost= 457117
#
# step 101644
# [[3 6 5]
#  [2 0 4]
#  [7 1 8]]
# action= down , depth= 101644 , step cost= 1 , total_cost= 457118
#
# step 101645
# [[3 6 5]
#  [0 2 4]
#  [7 1 8]]
# action= right , depth= 101645 , step cost= 2 , total_cost= 457120
#
# step 101646
# [[0 6 5]
#  [3 2 4]
#  [7 1 8]]
# action= down , depth= 101646 , step cost= 3 , total_cost= 457123
#
# step 101647
# [[6 0 5]
#  [3 2 4]
#  [7 1 8]]
# action= left , depth= 101647 , step cost= 6 , total_cost= 457129
#
# step 101648
# [[6 5 0]
#  [3 2 4]
#  [7 1 8]]
# action= left , depth= 101648 , step cost= 5 , total_cost= 457134
#
# step 101649
# [[6 5 4]
#  [3 2 0]
#  [7 1 8]]
# action= up , depth= 101649 , step cost= 4 , total_cost= 457138
#
# step 101650
# [[6 5 4]
#  [3 0 2]
#  [7 1 8]]
# action= right , depth= 101650 , step cost= 2 , total_cost= 457140
#
# step 101651
# [[6 5 4]
#  [0 3 2]
#  [7 1 8]]
# action= right , depth= 101651 , step cost= 3 , total_cost= 457143
#
# step 101652
# [[0 5 4]
#  [6 3 2]
#  [7 1 8]]
# action= down , depth= 101652 , step cost= 6 , total_cost= 457149
#
# step 101653
# [[5 0 4]
#  [6 3 2]
#  [7 1 8]]
# action= left , depth= 101653 , step cost= 5 , total_cost= 457154
#
# step 101654
# [[5 4 0]
#  [6 3 2]
#  [7 1 8]]
# action= left , depth= 101654 , step cost= 4 , total_cost= 457158
#
# step 101655
# [[5 4 2]
#  [6 3 0]
#  [7 1 8]]
# action= up , depth= 101655 , step cost= 2 , total_cost= 457160
#
# step 101656
# [[5 4 2]
#  [6 0 3]
#  [7 1 8]]
# action= right , depth= 101656 , step cost= 3 , total_cost= 457163
#
# step 101657
# [[5 4 2]
#  [0 6 3]
#  [7 1 8]]
# action= right , depth= 101657 , step cost= 6 , total_cost= 457169
#
# step 101658
# [[0 4 2]
#  [5 6 3]
#  [7 1 8]]
# action= down , depth= 101658 , step cost= 5 , total_cost= 457174
#
# step 101659
# [[4 0 2]
#  [5 6 3]
#  [7 1 8]]
# action= left , depth= 101659 , step cost= 4 , total_cost= 457178
#
# step 101660
# [[4 2 0]
#  [5 6 3]
#  [7 1 8]]
# action= left , depth= 101660 , step cost= 2 , total_cost= 457180
#
# step 101661
# [[4 2 3]
#  [5 6 0]
#  [7 1 8]]
# action= up , depth= 101661 , step cost= 3 , total_cost= 457183
#
# step 101662
# [[4 2 3]
#  [5 0 6]
#  [7 1 8]]
# action= right , depth= 101662 , step cost= 6 , total_cost= 457189
#
# step 101663
# [[4 2 3]
#  [0 5 6]
#  [7 1 8]]
# action= right , depth= 101663 , step cost= 5 , total_cost= 457194
#
# step 101664
# [[0 2 3]
#  [4 5 6]
#  [7 1 8]]
# action= down , depth= 101664 , step cost= 4 , total_cost= 457198
#
# step 101665
# [[2 0 3]
#  [4 5 6]
#  [7 1 8]]
# action= left , depth= 101665 , step cost= 2 , total_cost= 457200
#
# step 101666
# [[2 3 0]
#  [4 5 6]
#  [7 1 8]]
# action= left , depth= 101666 , step cost= 3 , total_cost= 457203
#
# step 101667
# [[2 3 6]
#  [4 5 0]
#  [7 1 8]]
# action= up , depth= 101667 , step cost= 6 , total_cost= 457209
#
# step 101668
# [[2 3 6]
#  [4 0 5]
#  [7 1 8]]
# action= right , depth= 101668 , step cost= 5 , total_cost= 457214
#
# step 101669
# [[2 3 6]
#  [4 1 5]
#  [7 0 8]]
# action= up , depth= 101669 , step cost= 1 , total_cost= 457215
#
# step 101670
# [[2 3 6]
#  [4 1 5]
#  [0 7 8]]
# action= right , depth= 101670 , step cost= 7 , total_cost= 457222
#
# step 101671
# [[2 3 6]
#  [0 1 5]
#  [4 7 8]]
# action= down , depth= 101671 , step cost= 4 , total_cost= 457226
#
# step 101672
# [[2 3 6]
#  [1 0 5]
#  [4 7 8]]
# action= left , depth= 101672 , step cost= 1 , total_cost= 457227
#
# step 101673
# [[2 3 6]
#  [1 5 0]
#  [4 7 8]]
# action= left , depth= 101673 , step cost= 5 , total_cost= 457232
#
# step 101674
# [[2 3 0]
#  [1 5 6]
#  [4 7 8]]
# action= down , depth= 101674 , step cost= 6 , total_cost= 457238
#
# step 101675
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 101675 , step cost= 3 , total_cost= 457241
#
# step 101676
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
# action= right , depth= 101676 , step cost= 2 , total_cost= 457243
#
# step 101677
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
# action= up , depth= 101677 , step cost= 1 , total_cost= 457244
#
# step 101678
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# action= up , depth= 101678 , step cost= 4 , total_cost= 457248
#
# step 101679
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# action= left , depth= 101679 , step cost= 7 , total_cost= 457255
#
# step 101680
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# action= left , depth= 101680 , step cost= 8 , total_cost= 457263
#
# Nodes Poped 156541
# Max Fringe Size 73568
# 'Search Complete'
